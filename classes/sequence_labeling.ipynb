# %% [markdown]
# Notebook prepared by Henrique Lopes Cardoso (hlc@fe.up.pt), based on [Named Entity Recognition with NLTK and SpaCy](https://towardsdatascience.com/named-entity-recognition-with-nltk-and-spacy-8c4a7d88e7da) by Susan Li.
#
# # SEQUENCE LABELING

# %% [markdown]
# ## Part Of Speech Tagging and Named Entity Recognition using NLTK or spaCy
#
# Part Of Speech (POS) tagging and Named Entity Recognition (NER) are the two most well known examples of sequence labeling tasks.

# %% [markdown]
# ### POS Tagging
#
# POS tagging consists of assigning to each word its morpho-syntactic category.
#
# NLTK includes a [POS tagger](https://www.nltk.org/api/nltk.tag.html) that we can use. We can check the tagset used by the tagger as follows:

# %%
import nltk

nltk.help.upenn_tagset()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2144/3186173429.py in <module>
#       1 import nltk
#       2
# ----> 3 nltk.help.upenn_tagset()
#
# ~\anaconda3\lib\site-packages\nltk\help.py in upenn_tagset(tagpattern)
#      25
#      26 def upenn_tagset(tagpattern=None):
# ---> 27     _format_tagset("upenn_tagset", tagpattern)
#      28
#      29
#
# ~\anaconda3\lib\site-packages\nltk\help.py in _format_tagset(tagset, tagpattern)
#      44
#      45 def _format_tagset(tagset, tagpattern=None):
# ---> 46     tagdict = load("help/tagsets/" + tagset + ".pickle")
#      47     if not tagpattern:
#      48         _print_entries(sorted(tagdict), tagdict)
#
# ~\anaconda3\lib\site-packages\nltk\data.py in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
#     748
#     749     # Load the resource.
# --> 750     opened_resource = _open(resource_url)
#     751
#     752     if format == "raw":
#
# ~\anaconda3\lib\site-packages\nltk\data.py in _open(resource_url)
#     874
#     875     if protocol is None or protocol.lower() == "nltk":
# --> 876         return find(path_, path + [""]).open()
#     877     elif protocol.lower() == "file":
#     878         # urllib might not use mode='rb', so handle this one ourselves:
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource tagsets not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('tagsets')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load help/tagsets/upenn_tagset.pickle
#
#   Searched in:
#     - 'C:\\Users\\ineso/nltk_data'
#     - 'C:\\Users\\ineso\\anaconda3\\nltk_data'
#     - 'C:\\Users\\ineso\\anaconda3\\share\\nltk_data'
#     - 'C:\\Users\\ineso\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\ineso\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
#     - ''
# **********************************************************************

# %% [markdown]
# To use the POS tagger, we first need to tokenize the text. Try out NLTK's [*pos_tag*](https://www.nltk.org/api/nltk.tag.html) with the following text, and analyse the POS tags you get:

# %%
from nltk import word_tokenize
from nltk import pos_tag

text = """European authorities fined Google a record $5.1 billion on Wednesday 
for abusing its power in the mobile phone market and 
ordered the company to alter its practices."""

# your code here
pos_tag(word_tokenize(text))
# Out:
# [('European', 'JJ'),
#  ('authorities', 'NNS'),
#  ('fined', 'VBD'),
#  ('Google', 'NNP'),
#  ('a', 'DT'),
#  ('record', 'NN'),
#  ('$', '$'),
#  ('5.1', 'CD'),
#  ('billion', 'CD'),
#  ('on', 'IN'),
#  ('Wednesday', 'NNP'),
#  ('for', 'IN'),
#  ('abusing', 'VBG'),
#  ('its', 'PRP$'),
#  ('power', 'NN'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('mobile', 'JJ'),
#  ('phone', 'NN'),
#  ('market', 'NN'),
#  ('and', 'CC'),
#  ('ordered', 'VBD'),
#  ('the', 'DT'),
#  ('company', 'NN'),
#  ('to', 'TO'),
#  ('alter', 'VB'),
#  ('its', 'PRP$'),
#  ('practices', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# #### Training a POS tagger in NLTK
#
# NLTK also allows you to train simple tagging models based on n-grams, where the model takes into account the tags assigned to the *n-1* words preceding the target word.
#
# Let's try that using [Floresta Sintá(c)tica](https://www.linguateca.pt/Floresta/), a Portuguese corpus annotated with POS tags (we will follow [this tuturial](https://www.nltk.org/howto/portuguese_en.html)):

# %%
nltk.download('floresta')
# Out:
# [nltk_data] Downloading package floresta to
# [nltk_data]     C:\Users\ineso\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\floresta.zip.
# True

# %%
from nltk.corpus import floresta

print(len(floresta.sents()))
print(floresta.sents())
print(floresta.tagged_sents())
# Out:
# 9266
# [['Um', 'revivalismo', 'refrescante'], ['O', '7_e_Meio', 'é', 'um', 'ex-libris', 'de', 'a', 'noite', 'algarvia', '.'], ...]
# [[('Um', '>N+art'), ('revivalismo', 'H+n'), ('refrescante', 'N<+adj')], [('O', '>N+art'), ('7_e_Meio', 'H+prop'), ('é', 'P+v-fin'), ('um', '>N+art'), ('ex-libris', 'H+n'), ('de', 'H+prp'), ('a', '>N+art'), ('noite', 'H+n'), ('algarvia', 'N<+adj'), ('.', '.')], ...]

# %% [markdown]
# The tags consist of some syntactic information, followed by a plus sign, followed by a conventional part-of-speech tag. We need to strip off the material before the plus sign:

# %%
def simplify_tag(t):
    if "+" in t:
        return t[t.index("+")+1:]
    else:
        return t

tsents = [[(w.lower(),simplify_tag(t)) for (w,t) in sent] for sent in floresta.tagged_sents()]
tsents
# Out:
# [[('um', 'art'), ('revivalismo', 'n'), ('refrescante', 'adj')],
#  [('o', 'art'),
#   ('7_e_meio', 'prop'),
#   ('é', 'v-fin'),
#   ('um', 'art'),
#   ('ex-libris', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('noite', 'n'),
#   ('algarvia', 'adj'),
#   ('.', '.')],
#  [('é', 'v-fin'),
#   ('uma', 'num'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('mais', 'adv'),
#   ('antigas', 'adj'),
#   ('discotecas', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('algarve', 'prop'),
#   (',', ','),
#   ('situada', 'v-pcp'),
#   ('em', 'prp'),
#   ('albufeira', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('continua', 'v-fin'),
#   ('a', 'prp'),
#   ('manter', 'v-inf'),
#   ('os', 'art'),
#   ('traços', 'n'),
#   ('decorativos', 'adj'),
#   ('e', 'conj-c'),
#   ('as', 'art'),
#   ('clientelas', 'n'),
#   ('de', 'prp'),
#   ('sempre', 'adv'),
#   ('.', '.')],
#  [('é', 'v-fin'),
#   ('um_pouco', 'adv'),
#   ('a', 'art'),
#   ('versão', 'n'),
#   ('de', 'prp'),
#   ('uma', 'art'),
#   ('espécie', 'n'),
#   ('de', 'prp'),
#   ('«', '«'),
#   ('outro', 'pron-det'),
#   ('lado', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('noite', 'n'),
#   (',', ','),
#   ('a', 'prp'),
#   ('meio', 'adj'),
#   ('caminho', 'n'),
#   ('entre', 'prp'),
#   ('os', 'art'),
#   ('devaneios', 'n'),
#   ('de', 'prp'),
#   ('uma', 'art'),
#   ('fauna', 'n'),
#   ('periférica', 'adj'),
#   (',', ','),
#   ('seja', 'v-fin'),
#   ('de', 'prp'),
#   ('lisboa', 'prop'),
#   (',', ','),
#   ('londres', 'prop'),
#   (',', ','),
#   ('dublin', 'prop'),
#   ('ou', 'conj-c'),
#   ('faro', 'n'),
#   ('e', 'conj-c'),
#   ('portimão', 'prop'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('a', 'art'),
#   ('postura', 'n'),
#   ('circunspecta', 'adj'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('fiéis', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('casa', 'n'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('de', 'prp'),
#   ('ela', 'pron-pers'),
#   ('esperam', 'v-fin'),
#   ('a', 'art'),
#   ('música', 'n'),
#   ('«', '«'),
#   ('geracionista', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('60', 'num'),
#   ('ou', 'conj-c'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('70', 'num'),
#   ('.', '.')],
#  [('não', 'adv'),
#   ('deixa', 'v-fin'),
#   ('de', 'prp'),
#   ('ser', 'v-inf'),
#   (',', ','),
#   ('em', 'prp'),
#   ('os', 'art'),
#   ('tempos', 'n'),
#   ('que', 'pron-indp'),
#   ('correm', 'v-fin'),
#   (',', ','),
#   ('um', 'art'),
#   ('certo', 'pron-det'),
#   ('«', '«'),
#   ('very_typical', 'n'),
#   ('algarvio', 'adj'),
#   (',', ','),
#   ('cabeça', 'n'),
#   ('de', 'prp'),
#   ('cartaz', 'n'),
#   ('para', 'prp'),
#   ('os', 'pron-det'),
#   ('que', 'pron-indp'),
#   ('querem', 'v-fin'),
#   ('fugir', 'v-inf'),
#   ('a', 'prp'),
#   ('algumas', 'pron-det'),
#   ('movimentações', 'n'),
#   ('nocturnas', 'adj'),
#   ('já', 'adv'),
#   ('a', 'prp'),
#   ('caminho', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('ritualização', 'n'),
#   ('de', 'prp'),
#   ('massas', 'n'),
#   (',', ','),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('género', 'n'),
#   ('«', '«'),
#   ('vamos', 'v-fin'),
#   ('todos', 'pron-det'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('calypso', 'prop'),
#   ('e', 'conj-c'),
#   ('encontramos-', 'v-fin'),
#   ('nos', 'pron-pers'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('locomia', 'prop'),
#   ('.', '.')],
#  [('e', 'conj-c'),
#   ('assim', 'adv'),
#   (',', ','),
#   ('a', 'prp'),
#   ('os', 'art'),
#   ('2,5', 'num'),
#   ('milhões', 'n'),
#   ('que', 'pron-indp'),
#   ('o', 'art'),
#   ('ministério_do_planeamento_e_administração_do_território', 'prop'),
#   ('já', 'adv'),
#   ('gasta', 'v-fin'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('pagamento', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('pessoal', 'n'),
#   ('afecto', 'v-pcp'),
#   ('a', 'prp'),
#   ('estes', 'pron-det'),
#   ('organismos', 'n'),
#   (',', ','),
#   ('vêm', 'v-fin'),
#   ('juntar-', 'v-inf'),
#   ('se', 'pron-pers'),
#   ('os', 'art'),
#   ('montantes', 'n'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('obras', 'n'),
#   ('propriamente', 'adv'),
#   ('ditas', 'adj'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('os', 'art'),
#   ('municípios', 'n'),
#   (',', ','),
#   ('já', 'adv'),
#   ('com', 'prp'),
#   ('projectos', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('mão', 'n'),
#   (',', ','),
#   ('vêm', 'v-fin'),
#   ('reivindicar', 'v-inf'),
#   ('junto', 'adv'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('executivo', 'n'),
#   (',', ','),
#   ('como', 'prp'),
#   ('salienta', 'v-fin'),
#   ('aquele', 'pron-det'),
#   ('membro', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('governo', 'prop'),
#   ('.', '.')],
#  [('e', 'conj-c'),
#   ('o', 'art'),
#   ('dinheiro', 'n'),
#   ('«', '«'),
#   ('não', 'adv'),
#   ('falta', 'v-fin'),
#   ('só', 'adv'),
#   ('a', 'prp'),
#   ('as', 'art'),
#   ('câmaras', 'n'),
#   (',', ','),
#   ('lembra', 'v-fin'),
#   ('o', 'art'),
#   ('secretário_de_estado', 'n'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('considera', 'v-fin'),
#   ('que', 'conj-s'),
#   ('a', 'art'),
#   ('solução', 'n'),
#   ('para', 'prp'),
#   ('as', 'art'),
#   ('autarquias', 'n'),
#   ('é', 'v-fin'),
#   ('«', '«'),
#   ('especializarem-', 'v-inf'),
#   ('se', 'pron-pers'),
#   ('em', 'prp'),
#   ('fundos', 'n'),
#   ('comunitários', 'adj'),
#   ('.', '.')],
#  [('mas', 'conj-c'),
#   ('como', 'adv'),
#   (',', ','),
#   ('se', 'conj-s'),
#   ('muitas', 'pron-det'),
#   ('não', 'adv'),
#   ('dispõem', 'v-fin'),
#   (',', ','),
#   ('em', 'prp'),
#   ('os', 'art'),
#   ('seus', 'pron-det'),
#   ('quadros', 'n'),
#   (',', ','),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('técnicos', 'n'),
#   ('necessários', 'adj'),
#   ('?', '?')],
#  [('«', '«'),
#   ('encomendem-', 'v-fin'),
#   ('nos', 'pron-pers'),
#   ('a', 'prp'),
#   ('projectistas', 'n'),
#   ('de_fora', 'pp'),
#   ('porque', 'conj-s'),
#   (',', ','),
#   ('se', 'conj-s'),
#   ('as', 'art'),
#   ('obras', 'n'),
#   ('vierem', 'v-fin'),
#   ('a', 'prp'),
#   ('ser', 'v-inf'),
#   ('financiadas', 'v-pcp'),
#   (',', ','),
#   ('eles', 'pron-pers'),
#   ('até', 'adv'),
#   ('saem', 'v-fin'),
#   ('de_graça', 'pp'),
#   (',', ','),
#   ('já_que', 'conj-s'),
#   (',', ','),
#   ('em', 'prp'),
#   ('esse', 'pron-det'),
#   ('caso', 'n'),
#   (',', ','),
#   ('«', '«'),
#   ('os', 'art'),
#   ('fundos', 'n'),
#   ('comunitários', 'adj'),
#   ('pagam', 'v-fin'),
#   ('os', 'art'),
#   ('projectos', 'n'),
#   (',', ','),
#   ('o', 'art'),
#   ('mesmo', 'pron-det'),
#   ('não', 'adv'),
#   ('acontecendo', 'v-ger'),
#   ('quando', 'adv'),
#   ('eles', 'pron-pers'),
#   ('são', 'v-fin'),
#   ('feitos', 'v-pcp'),
#   ('por', 'prp'),
#   ('os', 'art'),
#   ('gat', 'prop'),
#   (',', ','),
#   ('dado', 'v-pcp'),
#   ('serem', 'v-inf'),
#   ('organismos', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('estado', 'n'),
#   ('.', '.')],
#  [('essa', 'pron-det'),
#   ('poderá', 'v-fin'),
#   ('vir', 'v-inf'),
#   ('a', 'prp'),
#   ('ser', 'v-inf'),
#   ('uma', 'art'),
#   ('hipótese', 'n'),
#   (',', ','),
#   ('até', 'adv'),
#   ('porque', 'conj-s'),
#   (',', ','),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('terreno', 'n'),
#   (',', ','),
#   ('a', 'art'),
#   ('capacidade', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('gat', 'prop'),
#   ('está', 'v-fin'),
#   ('cada_vez_mais', 'adv'),
#   ('enfraquecida', 'v-pcp'),
#   ('.', '.')],
#  [('alguns', 'pron-det'),
#   ('até', 'adv'),
#   ('já', 'adv'),
#   ('desapareceram', 'v-fin'),
#   (',', ','),
#   ('como', 'adv'),
#   ('o', 'pron-det'),
#   ('de', 'prp'),
#   ('castro_verde', 'prop'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('outros', 'pron-det'),
#   ('têm', 'v-fin'),
#   ('vindo', 'v-pcp'),
#   ('a', 'prp'),
#   ('perder', 'v-inf'),
#   ('quadros', 'n'),
#   ('.', '.')],
#  [('um', 'art'),
#   ('arquitecto', 'n'),
#   ('para', 'prp'),
#   ('800', 'num'),
#   ('km2', 'n')],
#  [('«', '«'),
#   ('orelhas', 'n'),
#   ('para', 'prp'),
#   ('os', 'art'),
#   ('computadores', 'n')],
#  [('o', 'art'),
#   ('primeiro', 'adj'),
#   ('fabricante', 'n'),
#   ('mundial', 'adj'),
#   ('de', 'prp'),
#   ('«', '«'),
#   ('ratos', 'n'),
#   ('para', 'prp'),
#   ('computador', 'n'),
#   (',', ','),
#   ('a', 'art'),
#   ('empresa', 'n'),
#   ('suíça', 'adj'),
#   ('logitech', 'prop'),
#   (',', ','),
#   ('apresentou', 'v-fin'),
#   ('esta', 'pron-det'),
#   ('semana', 'n'),
#   ('em', 'prp'),
#   ('uma', 'art'),
#   ('feira', 'n'),
#   ('especializada', 'v-pcp'),
#   ('que', 'pron-indp'),
#   ('teve', 'v-fin'),
#   ('lugar', 'n'),
#   ('em', 'prp'),
#   ('basileia', 'prop'),
#   ('{', '{'),
#   ('suíça', 'prop'),
#   ('}', '}'),
#   ('um', 'art'),
#   ('equipamento', 'n'),
#   ('periférico', 'adj'),
#   ('denominado', 'v-pcp'),
#   ('«', '«'),
#   ('audioman', 'prop'),
#   ('que', 'pron-indp'),
#   ('permitirá', 'v-fin'),
#   ('dotar', 'v-inf'),
#   ('os', 'art'),
#   ('computadores', 'n'),
#   ('de', 'prp'),
#   ('«', '«'),
#   ('orelhas', 'n'),
#   ('.', '.')],
#  [('segundo', 'prp'),
#   ('a', 'art'),
#   ('empresa', 'n'),
#   (',', ','),
#   ('o', 'art'),
#   ('aparelho', 'n'),
#   ('permite', 'v-fin'),
#   ('que', 'conj-s'),
#   ('o', 'art'),
#   ('aparelho', 'n'),
#   ('grave', 'v-fin'),
#   ('e', 'conj-c'),
#   ('transcreva', 'v-fin'),
#   ('a', 'art'),
#   ('voz', 'n'),
#   ('humana', 'adj'),
#   ('.', '.')],
#  [('«', '«'),
#   ('estamos', 'v-fin'),
#   ('a', 'prp'),
#   ('dotar', 'v-inf'),
#   ('os', 'art'),
#   ('computadores', 'n'),
#   ('de', 'prp'),
#   ('um', 'art'),
#   ('novo', 'adj'),
#   ('sentido', 'n'),
#   ('disse', 'v-fin'),
#   ('steve_d\x92_averio', 'prop'),
#   (',', ','),
#   ('director', 'n'),
#   ('de', 'prp'),
#   ('marketing', 'n'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('europa', 'prop'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('logitech', 'prop'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('audioman', 'prop'),
#   ('foi', 'v-fin'),
#   ('desenvolvido', 'v-pcp'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('suíça', 'prop'),
#   ('em', 'prp'),
#   ('apenas', 'adv'),
#   ('sete', 'num'),
#   ('meses', 'n'),
#   ('e', 'conj-c'),
#   ('compõe-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('de', 'prp'),
#   ('um', 'art'),
#   ('microfone', 'n'),
#   ('e', 'conj-c'),
#   ('de', 'prp'),
#   ('um', 'art'),
#   ('altifalante', 'n'),
#   ('que', 'pron-indp'),
#   ('se', 'pron-pers'),
#   ('podem', 'v-fin'),
#   ('acoplar', 'v-inf'),
#   ('facilmente', 'adv'),
#   ('a', 'prp'),
#   ('um', 'art'),
#   ('computador', 'n'),
#   (',', ','),
#   ('devendo', 'v-ger'),
#   ('ser', 'v-inf'),
#   ('comercializado', 'v-pcp'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('preço', 'n'),
#   ('de', 'prp'),
#   ('290', 'num'),
#   ('francos', 'n'),
#   ('suíços', 'adj'),
#   ('{', '{'),
#   ('28', 'num'),
#   ('contos', 'n'),
#   ('}', '}'),
#   ('.', '.')],
#  [('junqueiro', 'prop'),
#   ('foi', 'v-fin'),
#   ('ainda', 'adv'),
#   ('confrontado', 'v-pcp'),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('facto', 'n'),
#   ('de', 'prp'),
#   ('não', 'adv'),
#   ('ter', 'v-inf'),
#   ('falado', 'v-pcp'),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('ministro', 'n'),
#   ('antes', 'adv'),
#   ('de', 'prp'),
#   ('avançar', 'v-inf'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('proposta', 'n'),
#   ('.', '.')],
#  [('joão_cravinho', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('integra', 'v-fin'),
#   ('a', 'art'),
#   ('comitiva', 'n'),
#   ('de', 'prp'),
#   ('jorge_sampaio', 'prop'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('visita', 'n'),
#   ('de', 'prp'),
#   ('estado', 'n'),
#   ('a', 'prp'),
#   ('moçambique', 'prop'),
#   (',', ','),
#   ('ainda', 'adv'),
#   ('não', 'adv'),
#   ('reagiu', 'v-fin'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('carta', 'n'),
#   ('que', 'pron-indp'),
#   ('o', 'art'),
#   ('dirigente', 'n'),
#   ('socialista', 'adj'),
#   ('lhe', 'pron-pers'),
#   ('enviou', 'v-fin'),
#   ('.', '.')],
#  [('«', '«'),
#   ('não', 'adv'),
#   ('estou', 'v-fin'),
#   ('a', 'prp'),
#   ('ver', 'v-inf'),
#   ('que', 'conj-s'),
#   (',', ','),
#   ('para', 'prp'),
#   ('emitir', 'v-inf'),
#   ('uma', 'art'),
#   ('opinião', 'n'),
#   (',', ','),
#   ('nós', 'pron-pers'),
#   ('tivéssemos', 'v-fin'),
#   ('de', 'prp'),
#   ('informar', 'v-inf'),
#   ('previamente', 'adv'),
#   ('o', 'art'),
#   ('ministro', 'n'),
#   (',', ','),
#   ('afirmou', 'v-fin'),
#   ('.', '.')],
#  [('«', '«'),
#   ('o', 'art'),
#   ('senhor', 'n'),
#   ('ministro', 'n'),
#   ('interpretará', 'v-fin'),
#   ('esta', 'pron-det'),
#   ('sugestão', 'n'),
#   ('como', 'prp'),
#   ('entender', 'v-fin'),
#   ('.', '.')],
#  [('junqueiro', 'prop'),
#   ('recordou', 'v-fin'),
#   ('ainda', 'adv'),
#   ('que', 'conj-s'),
#   (',', ','),
#   ('em', 'prp'),
#   ('as', 'art'),
#   ('últimas', 'adj'),
#   ('autárquicas', 'adj'),
#   (',', ','),
#   ('o', 'art'),
#   ('igat', 'prop'),
#   ('suspendeu', 'v-fin'),
#   ('as', 'art'),
#   ('suas', 'pron-det'),
#   ('actividades', 'n'),
#   ('um', 'num'),
#   ('mês', 'n'),
#   ('antes', 'adv'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('eleições', 'n'),
#   ('.', '.')],
#  [('além', 'adv'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('museu_do_ar', 'prop'),
#   (',', ','),
#   ('o', 'art'),
#   ('projecto', 'n'),
#   ('gira', 'v-fin'),
#   ('em_torno_de', 'prp'),
#   ('o', 'art'),
#   ('parque', 'n'),
#   ('temático', 'adj'),
#   ('propriamente', 'adv'),
#   ('dito', 'v-pcp'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('zona', 'n'),
#   ('lúdica', 'adj'),
#   (',', ','),
#   ('com', 'prp'),
#   ('os', 'art'),
#   ('divertimentos', 'n'),
#   (',', ','),
#   ('áreas', 'n'),
#   ('comerciais', 'adj'),
#   ('de', 'prp'),
#   ('«', '«'),
#   ('souvenirs', 'n'),
#   ('e', 'conj-c'),
#   ('de', 'prp'),
#   ('restauração', 'n'),
#   (',', ','),
#   ('compreende', 'v-fin'),
#   ('espaços', 'n'),
#   ('distintos', 'adj'),
#   ('para', 'prp'),
#   ('os', 'art'),
#   ('vários', 'pron-det'),
#   ('temas', 'n'),
#   (',', ','),
#   ('ainda', 'adv'),
#   ('em', 'prp'),
#   ('análise', 'n'),
#   (',', ','),
#   ('tais', 'pron-det'),
#   ('como', 'adv'),
#   ('portugal', 'prop'),
#   (',', ','),
#   ('japão', 'prop'),
#   (',', ','),
#   ('brasil', 'prop'),
#   (',', ','),
#   ('áfrica', 'prop'),
#   ('e', 'conj-c'),
#   ('far-west', 'prop'),
#   ('.', '.')],
#  [('os', 'art'),
#   ('quatro', 'num'),
#   ('primeiros', 'adj'),
#   ('temas', 'n'),
#   ('destinam-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('a', 'prp'),
#   ('mostrar', 'v-inf'),
#   ('o', 'art'),
#   ('papel', 'n'),
#   ('de', 'prp'),
#   ('portugal', 'prop'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('mundo', 'n'),
#   ('e', 'conj-c'),
#   ('o', 'art'),
#   ('quinto', 'adj'),
#   (',', ','),
#   ('o', 'art'),
#   ('único', 'adj'),
#   ('sem', 'prp'),
#   ('relação', 'n'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('história', 'n'),
#   ('nacional', 'adj'),
#   (',', ','),
#   ('é', 'v-fin'),
#   ('justificado', 'v-pcp'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('experiência', 'n'),
#   ('de', 'prp'),
#   ('barcelona', 'prop'),
#   ('{', '{'),
#   ('port_aventura', 'prop'),
#   ('}', '}'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('regista', 'v-fin'),
#   ('assinalável', 'adj'),
#   ('sucesso', 'n'),
#   ('.', '.')],
#  [('uma', 'art'),
#   ('«', '«'),
#   ('zona', 'n'),
#   ('petting', 'n'),
#   ('anexa', 'adj'),
#   (',', ','),
#   ('em', 'prp'),
#   ('cooperação', 'n'),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('jardim_zoológico_de_lisboa', 'prop'),
#   (',', ','),
#   ('destina-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('a', 'prp'),
#   ('permitir', 'v-inf'),
#   ('o', 'art'),
#   ('contacto', 'n'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('crianças', 'n'),
#   ('com', 'prp'),
#   ('animais', 'n'),
#   ('.', '.')],
#  [('tudo', 'pron-indp'),
#   (',', ','),
#   ('claro', 'adv'),
#   ('está', 'v-fin'),
#   (',', ','),
#   ('muito', 'adv'),
#   ('arborizado', 'v-pcp'),
#   ('.', '.')],
#  [('seis', 'num'),
#   ('milhões', 'n'),
#   ('em', 'prp'),
#   ('dez', 'num'),
#   ('anos', 'n')],
#  [('o', 'art'),
#   ('museu', 'n'),
#   (',', ','),
#   ('a', 'prp'),
#   ('desenvolver', 'v-inf'),
#   ('sob', 'prp'),
#   ('orientação', 'n'),
#   ('de', 'prp'),
#   ('uma', 'art'),
#   ('comissão', 'n'),
#   ('de', 'prp'),
#   ('notáveis', 'adj'),
#   (',', ','),
#   ('dirigida', 'v-pcp'),
#   ('por', 'prp'),
#   ('o', 'art'),
#   ('presidente_da_república', 'prop'),
#   (',', ','),
#   ('está', 'v-fin'),
#   ('orçado', 'v-pcp'),
#   ('em', 'prp'),
#   ('seis', 'num'),
#   ('milhões', 'n'),
#   ('de', 'prp'),
#   ('contos', 'n'),
#   (',', ','),
#   ('valor', 'n'),
#   ('incomportável', 'adj'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('força_aérea', 'prop'),
#   ('.', '.')],
#  [('de', 'prp'),
#   ('aí', 'adv'),
#   ('que', 'adv'),
#   ('a', 'art'),
#   ('cameron_hall', 'prop'),
#   ('tenha', 'v-fin'),
#   ('caído', 'v-pcp'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('céu', 'n'),
#   ('.', '.')],
#  [('«', '«'),
#   ('a', 'art'),
#   ('proposta', 'n'),
#   ('é', 'v-fin'),
#   ('muito', 'adv'),
#   ('bem', 'adv'),
#   ('vista', 'v-pcp'),
#   (',', ','),
#   ('porque', 'conj-s'),
#   ('será', 'v-fin'),
#   ('mais', 'adv'),
#   ('vantajosa', 'adj'),
#   ('do_que', 'conj-s'),
#   ('se', 'conj-s'),
#   ('houver', 'v-fin'),
#   ('só', 'adv'),
#   ('um', 'art'),
#   ('pólo', 'n'),
#   ('de', 'prp'),
#   ('interesse', 'n'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('local', 'n'),
#   (',', ','),
#   ('afirmou', 'v-fin'),
#   ('o', 'art'),
#   ('major', 'n'),
#   ('carlos_barbosa', 'prop'),
#   (',', ','),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('relações_públicas', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('força_aérea', 'prop'),
#   (',', ','),
#   ('admitindo', 'v-ger'),
#   ('que', 'conj-s'),
#   (',', ','),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('parque', 'n'),
#   ('temático', 'adj'),
#   (',', ','),
#   ('«', '«'),
#   ('se', 'conj-s'),
#   ('o', 'art'),
#   ('interesse', 'n'),
#   ('for', 'v-fin'),
#   ('diversificado', 'v-pcp'),
#   (',', ','),
#   ('toda_a_gente', 'pron-indp'),
#   ('fica', 'v-fin'),
#   ('a', 'prp'),
#   ('ganhar', 'v-inf'),
#   ('.', '.')],
#  [('a', 'prp'),
#   ('pouco', 'pron-det'),
#   ('mais_de', 'adv'),
#   ('um', 'num'),
#   ('mês', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('lançamento', 'n'),
#   ('nacional', 'adj'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('rendimento_mínimo_garantido', 'prop'),
#   ('{', '{'),
#   ('rmg', 'prop'),
#   ('}', '}'),
#   (',', ','),
#   ('o', 'art'),
#   ('número', 'n'),
#   ('de', 'prp'),
#   ('famílias', 'n'),
#   ('já', 'adv'),
#   ('abrangidas', 'v-pcp'),
#   ('por', 'prp'),
#   ('os', 'art'),
#   ('projectos-piloto', 'n'),
#   ('de', 'prp'),
#   ('este', 'pron-det'),
#   ('programa', 'n'),
#   ('de', 'prp'),
#   ('apoio', 'n'),
#   ('a', 'prp'),
#   ('os', 'art'),
#   ('agregados', 'n'),
#   ('mais', 'adv'),
#   ('desfavorecidos', 'v-pcp'),
#   ('não', 'adv'),
#   ('pára', 'v-fin'),
#   ('de', 'prp'),
#   ('aumentar', 'v-inf'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('último', 'adj'),
#   ('diagnóstico', 'n'),
#   ('elaborado', 'v-pcp'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('comissão_nacional_do_rmg', 'prop'),
#   ('não', 'adv'),
#   ('deixa', 'v-fin'),
#   ('dúvidas', 'n'),
#   (';', ';')],
#  [('7.777', 'num'),
#   ('famílias', 'n'),
#   (',', ','),
#   ('totalizando', 'v-ger'),
#   ('26.668', 'num'),
#   ('pessoas', 'n'),
#   (',', ','),
#   ('estão', 'v-fin'),
#   ('já', 'adv'),
#   ('a', 'prp'),
#   ('usufruir', 'v-inf'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('rendimento', 'n'),
#   ('destinado', 'v-pcp'),
#   ('a', 'prp'),
#   ('garantir', 'v-inf'),
#   ('condições', 'n'),
#   ('consideradas', 'v-pcp'),
#   ('mínimas', 'adj'),
#   ('de', 'prp'),
#   ('sobrevivência', 'n'),
#   ('e', 'conj-c'),
#   ('reinserção', 'n'),
#   ('de', 'prp'),
#   ('cidadãos', 'n'),
#   ('excluídos', 'v-pcp'),
#   ('socialmente', 'adv'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('balanço', 'n'),
#   ('a', 'prp'),
#   ('que', 'pron-indp'),
#   ('o', 'art'),
#   ('público', 'prop'),
#   ('teve', 'v-fin'),
#   ('acesso', 'n'),
#   ('traçado', 'v-pcp'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('comissão', 'n'),
#   ('revela', 'v-fin'),
#   ('que', 'conj-s'),
#   ('o', 'art'),
#   ('número', 'n'),
#   ('de', 'prp'),
#   ('pessoas', 'n'),
#   ('abrangidas', 'v-pcp'),
#   ('por', 'prp'),
#   ('o', 'art'),
#   ('rmg', 'prop'),
#   ('aumentou', 'v-fin'),
#   ('36', 'num'),
#   ('por_cento', 'n'),
#   ('relativamente_a', 'prp'),
#   ('o', 'art'),
#   ('último', 'adj'),
#   ('balanço', 'n'),
#   ('de', 'prp'),
#   ('30', 'num'),
#   ('de', 'prp'),
#   ('março', 'n'),
#   ('.', '.')],
#  [('este', 'pron-det'),
#   ('crescimento', 'n'),
#   ('«', '«'),
#   ('resulta', 'v-fin'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('opção', 'n'),
#   ('de', 'prp'),
#   ('alargar', 'v-inf'),
#   ('o', 'art'),
#   ('número', 'n'),
#   ('de', 'prp'),
#   ('projectos-piloto', 'n'),
#   (',', ','),
#   ('de_modo_a', 'prp'),
#   ('cobrir', 'v-inf'),
#   ('uma', 'art'),
#   ('parte', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('território', 'n'),
#   ('nacional', 'adj'),
#   ('até', 'prp'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('dia', 'n'),
#   ('1', 'num'),
#   ('de', 'prp'),
#   ('julho', 'n'),
#   (',', ','),
#   ('referiu', 'v-fin'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('público', 'prop'),
#   ('o', 'art'),
#   ('presidente_da_comissão_nacional_do_rmg', 'n'),
#   (',', ','),
#   ('paulo_pedroso', 'prop'),
#   ('.', '.')],
#  [('para', 'prp'),
#   ('tal', 'pron-det'),
#   (',', ','),
#   ('referiu', 'v-fin'),
#   ('aquele', 'pron-det'),
#   ('responsável', 'adj'),
#   (',', ','),
#   ('«', '«'),
#   ('foram', 'v-fin'),
#   ('montadas', 'v-pcp'),
#   ('mais', 'pron-det'),
#   ('estruturas', 'n'),
#   (',', ','),
#   ('mais', 'pron-det'),
#   ('zonas', 'n'),
#   ('estão', 'v-fin'),
#   ('abrangidas', 'v-pcp'),
#   ('e', 'conj-c'),
#   (',', ','),
#   ('por', 'prp'),
#   ('isso', 'pron-indp'),
#   (',', ','),
#   ('mais', 'pron-det'),
#   ('pessoas', 'n'),
#   ('se', 'pron-pers'),
#   ('podem', 'v-fin'),
#   ('candidatar', 'v-inf'),
#   ('.', '.')],
#  [('e', 'conj-c'),
#   ('tantos', 'pron-det'),
#   ('foram', 'v-fin'),
#   ('os', 'art'),
#   ('candidatos', 'n'),
#   ('que', 'conj-s'),
#   ('o', 'art'),
#   ('período', 'n'),
#   ('destinado', 'v-pcp'),
#   ('a', 'prp'),
#   ('testar', 'v-inf'),
#   ('a', 'art'),
#   ('aplicação', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('rmg', 'prop'),
#   ('acabaria', 'v-fin'),
#   ('por', 'prp'),
#   ('ceder', 'v-inf'),
#   ('lugar', 'n'),
#   ('a', 'prp'),
#   ('um', 'art'),
#   ('processo', 'n'),
#   ('efectivo', 'adj'),
#   ('de', 'prp'),
#   ('financiamento', 'n'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('instituição', 'n'),
#   ('de', 'prp'),
#   ('este', 'pron-det'),
#   ('direito', 'n'),
#   ('só', 'adv'),
#   ('será', 'v-inf'),
#   (',', ','),
#   ('contudo', 'adv'),
#   (',', ','),
#   ('efectivado', 'v-pcp'),
#   ('depois', 'adv'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('lançamento', 'n'),
#   ('nacional', 'adj'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('projecto', 'n'),
#   ('dentro_de', 'prp'),
#   ('pouco', 'pron-det'),
#   ('mais_de', 'adv'),
#   ('um', 'num'),
#   ('mês', 'n'),
#   ('.', '.')],
#  [('mais', 'adv'),
#   ('metafórico', 'adj'),
#   ('foi', 'v-fin'),
#   ('o', 'art'),
#   ('secretário_de_estado_do_desenvolvimento_regional', 'n'),
#   (',', ','),
#   ('adriano_pimpão', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('comparou', 'v-fin'),
#   ('o', 'art'),
#   ('acordo', 'n'),
#   ('a', 'prp'),
#   ('«', '«'),
#   ('uma', 'art'),
#   ('embraiagem', 'n'),
#   ('.', '.')],
#  [('porque', 'conj-s'),
#   ('é', 'v-fin'),
#   ('a', 'art'),
#   ('embraiagem', 'n'),
#   ('«', '«'),
#   ('que', 'pron-indp'),
#   ('põe', 'v-fin'),
#   ('o', 'art'),
#   ('motor', 'n'),
#   ('em', 'prp'),
#   ('contacto', 'n'),
#   ('com', 'prp'),
#   ('as', 'art'),
#   ('rodas', 'n'),
#   ('que', 'pron-indp'),
#   ('geram', 'v-fin'),
#   ('o', 'art'),
#   ('movimento', 'n'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('para', 'prp'),
#   ('nós', 'pron-pers'),
#   ('é', 'v-fin'),
#   ('o', 'art'),
#   ('desenvolvimento', 'n'),
#   ('.', '.')],
#  [('para', 'prp'),
#   ('que', 'conj-s'),
#   ('não', 'adv'),
#   ('surjam', 'v-fin'),
#   ('avarias', 'n'),
#   (',', ','),
#   ('pimpão', 'n'),
#   ('pediu', 'v-fin'),
#   ('a', 'prp'),
#   ('os', 'art'),
#   ('presentes', 'n'),
#   ('que', 'conj-s'),
#   ('se', 'pron-pers'),
#   ('empenhem', 'v-fin'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('execução', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('termos', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('acordo', 'n'),
#   (',', ','),
#   ('sob_pena_de', 'prp'),
#   ('a', 'art'),
#   ('embraiagem', 'n'),
#   ('se', 'pron-pers'),
#   ('transformar', 'v-inf'),
#   ('em', 'prp'),
#   ('«', '«'),
#   ('travão', 'n'),
#   ('.', '.')],
#  [('a_propósito', 'pp'),
#   (',', ','),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('museu_da_segunda_guerra_mundial', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('aí', 'adv'),
#   ('foi', 'v-fin'),
#   ('aberto', 'v-pcp'),
#   (',', ','),
#   ('a', 'art'),
#   ('história', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('maior', 'adj'),
#   ('guerra', 'n'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('continente', 'n'),
#   ('europeu', 'adj'),
#   ('começa', 'v-fin'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('fotografia', 'n'),
#   ('de', 'prp'),
#   ('estaline', 'prop'),
#   ('a', 'prp'),
#   ('cumprimentar', 'v-inf'),
#   ('o', 'art'),
#   ('ministro_dos_negócios_estrangeiros', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('alemanha', 'prop'),
#   ('nazi', 'adj'),
#   (',', ','),
#   ('ou_seja', 'adv'),
#   (',', ','),
#   ('a', 'art'),
#   ('guerra', 'n'),
#   ('começa', 'v-fin'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('assinatura', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('pacto_molotov-ribbentrop', 'prop'),
#   ('.', '.')],
#  [('em', 'prp'),
#   ('a', 'art'),
#   ('cerimónia', 'n'),
#   ('de', 'prp'),
#   ('inauguração', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('edifício', 'n'),
#   (',', ','),
#   ('ieltsin', 'prop'),
#   ('declarou', 'v-fin'),
#   ('perante', 'prp'),
#   ('mais_de', 'adv'),
#   ('cem', 'num'),
#   ('mil', 'num'),
#   ('pessoas', 'n'),
#   ('que', 'conj-s'),
#   ('«', '«'),
#   ('a', 'art'),
#   ('rússia', 'prop'),
#   ('está', 'v-fin'),
#   ('perto_de', 'prp'),
#   ('a', 'art'),
#   ('estabilidade', 'n'),
#   ('política', 'adj'),
#   ('e', 'conj-c'),
#   ('que', 'conj-s'),
#   ('todos_os', 'pron-det'),
#   ('problemas', 'n'),
#   ('podem', 'v-fin'),
#   ('ser', 'v-inf'),
#   ('resolvidos', 'v-pcp'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('mesa', 'n'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('conversações', 'n'),
#   ('.', '.')],
#  [('talvez', 'adv'),
#   ('entusiasmado', 'v-pcp'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('festa', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('vitória', 'n'),
#   (',', ','),
#   ('o', 'art'),
#   ('presidente', 'n'),
#   ('russo', 'adj'),
#   ('afirmou', 'v-fin'),
#   ('que', 'conj-s'),
#   ('«', '«'),
#   ('chegará', 'v-fin'),
#   ('o', 'art'),
#   ('dia', 'n'),
#   ('em', 'prp'),
#   ('que', 'pron-indp'),
#   ('a', 'art'),
#   ('rússia', 'prop'),
#   ('ajudará', 'v-fin'),
#   ('o', 'art'),
#   ('ocidente', 'n'),
#   ('.', '.')],
#  [('as', 'art'),
#   ('cerimónias', 'n'),
#   ('oficiais', 'adj'),
#   ('terminaram', 'v-fin'),
#   ('com', 'prp'),
#   ('desfiles', 'n'),
#   ('militares', 'adj'),
#   ('e', 'conj-c'),
#   ('recriações', 'n'),
#   ('de', 'prp'),
#   ('combates', 'n'),
#   ('aéreos', 'adj'),
#   ('entre', 'prp'),
#   ('os', 'art'),
#   ('aviadores', 'n'),
#   ('soviéticos', 'adj'),
#   ('e', 'conj-c'),
#   ('alemães', 'adj'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('festa', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('oposição', 'n')],
#  [('co-produção', 'n'),
#   ('franco-egípcia', 'adj'),
#   (',', ','),
#   ('«', '«'),
#   ('o_emigrante', 'prop'),
#   ('»', '»'),
#   ('inspira-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('história', 'n'),
#   ('de', 'prp'),
#   ('josé', 'prop'),
#   (',', ','),
#   ('filho', 'n'),
#   ('de', 'prp'),
#   ('jacob', 'prop'),
#   (',', ','),
#   ('contando', 'v-ger'),
#   ('o', 'art'),
#   ('percurso', 'n'),
#   ('de', 'prp'),
#   ('ram', 'prop'),
#   ('que', 'pron-indp'),
#   (',', ','),
#   ('há', 'v-fin'),
#   ('3000', 'num'),
#   ('anos', 'n'),
#   (',', ','),
#   ('decide', 'v-fin'),
#   ('abandonar', 'v-inf'),
#   ('a', 'art'),
#   ('sua', 'pron-det'),
#   ('terra', 'n'),
#   ('árida', 'adj'),
#   ('para', 'prp'),
#   ('se', 'pron-pers'),
#   ('instalar', 'v-inf'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('egipto', 'prop'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('faraós', 'n'),
#   (',', ','),
#   ('centro', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('civilização', 'n'),
#   ('.', '.')],
#  [('tomando', 'v-ger'),
#   ('a', 'art'),
#   ('defesa', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('filme', 'n'),
#   ('de', 'prp'),
#   ('chahine', 'prop'),
#   (',', ','),
#   ('em', 'prp'),
#   ('uma', 'art'),
#   ('sala', 'n'),
#   ('atulhada', 'v-pcp'),
#   (',', ','),
#   ('o', 'art'),
#   ('bastonário', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('advogados', 'n'),
#   (',', ','),
#   ('ahmed_al-khawaga', 'prop'),
#   (',', ','),
#   ('replicou', 'v-fin'),
#   ('que', 'conj-s'),
#   ('o', 'art'),
#   ('realizador', 'n'),
#   ('egípcio', 'adj'),
#   ('se', 'pron-pers'),
#   ('inspirou', 'v-fin'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('história', 'n'),
#   ('de', 'prp'),
#   ('josé', 'prop'),
#   (',', ','),
#   ('«', '«'),
#   ('mas', 'conj-c'),
#   ('não', 'adv'),
#   ('se', 'pron-pers'),
#   ('afastou', 'v-fin'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('palavras', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('corão', 'prop'),
#   ('que', 'pron-indp'),
#   ('evoca', 'v-fin'),
#   (',', ','),
#   ('em', 'prp'),
#   ('termos', 'n'),
#   ('claros', 'adj'),
#   (',', ','),
#   ('as', 'art'),
#   ('propostas', 'n'),
#   ('feitas', 'v-pcp'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('profeta', 'n'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('esposa', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('mestre', 'n'),
#   ('que', 'pron-indp'),
#   ('o', 'pron-pers'),
#   ('comprou', 'v-fin'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('chegada', 'n'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('egipto', 'prop'),
#   ('.', '.')],
#  [('quanto_a', 'prp'),
#   ('as', 'art'),
#   ('acusações', 'n'),
#   ('contra', 'prp'),
#   ('a', 'art'),
#   ('frança', 'prop'),
#   (',', ','),
#   ('o', 'art'),
#   ('advogado', 'n'),
#   ('de', 'prp'),
#   ('defesa', 'n'),
#   ('passou', 'v-fin'),
#   ('também', 'adv'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('ofensiva', 'n'),
#   (';', ';')],
#  [('«', '«'),
#   ('eu', 'pron-pers'),
#   ('não', 'adv'),
#   ('sou', 'v-fin'),
#   ('francês', 'adj'),
#   ('para', 'prp'),
#   ('falar', 'v-inf'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('cultura', 'n'),
#   ('francesa', 'adj'),
#   (',', ','),
#   ('mas', 'conj-c'),
#   ('sei', 'v-fin'),
#   ('que', 'conj-s'),
#   ('ela', 'pron-pers'),
#   ('deu', 'v-fin'),
#   ('uma', 'art'),
#   ('contribuição', 'n'),
#   ('importante', 'adj'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('cultura', 'n'),
#   ('egípcia', 'adj'),
#   ('.', '.')],
#  [('e', 'conj-c'),
#   ('uma_vez_que', 'conj-s'),
#   ('um', 'num'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('nossos', 'pron-det'),
#   ('artistas', 'n'),
#   ('conclui', 'v-fin'),
#   ('um', 'art'),
#   ('acordo', 'n'),
#   ('com', 'prp'),
#   ('um', 'art'),
#   ('artista', 'n'),
#   ('francês', 'adj'),
#   (',', ','),
#   ('isso', 'pron-indp'),
#   ('não', 'adv'),
#   ('nos', 'pron-pers'),
#   ('desonra', 'v-fin'),
#   ('.', '.')],
#  [('título', 'n'), (';', ';'), ('the_music_of_chance', 'prop')],
#  [('autor', 'n'), (';', ';'), ('paul_auster', 'prop')],
#  [('o', 'art'),
#   ('último', 'adj'),
#   ('romance', 'n'),
#   ('de', 'prp'),
#   ('paul_auster', 'prop'),
#   ('que', 'pron-indp'),
#   ('ainda', 'adv'),
#   ('não', 'adv'),
#   ('está', 'v-fin'),
#   ('traduzido', 'v-pcp'),
#   ('.', '.')],
#  [('nashe', 'prop'),
#   ('encontra', 'v-fin'),
#   ('pozzi', 'prop'),
#   (',', ','),
#   ('um', 'art'),
#   ('jogador', 'n'),
#   (',', ','),
#   ('com', 'prp'),
#   ('quem', 'pron-indp'),
#   ('inicia', 'v-fin'),
#   ('um', 'art'),
#   ('póquer', 'n'),
#   ('extravagante', 'adj'),
#   ('.', '.')],
#  [('em', 'prp'),
#   ('o', 'art'),
#   ('imenso', 'adj'),
#   ('desacerto', 'n'),
#   ('que', 'pron-indp'),
#   ('foi', 'v-fin'),
#   ('a', 'art'),
#   ('defesa', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('penafiel', 'prop'),
#   (',', ','),
#   ('o', 'art'),
#   ('capitão', 'n'),
#   ('vasco', 'prop'),
#   ('foi', 'v-fin'),
#   ('o', 'art'),
#   ('homem', 'n'),
#   ('que', 'pron-indp'),
#   ('ainda', 'adv'),
#   ('segurou', 'v-fin'),
#   ('as', 'art'),
#   ('pontas', 'n'),
#   ('.', '.')],
#  [('seguro', 'adj'),
#   (',', ','),
#   ('eficiente', 'adj'),
#   (',', ','),
#   ('decidido', 'v-pcp'),
#   ('tivesse', 'v-fin'),
#   ('o', 'art'),
#   ('penafiel', 'prop'),
#   ('outro', 'pron-det'),
#   ('vasco', 'prop'),
#   ('e', 'conj-c'),
#   ('provavelmente', 'adv'),
#   ('o', 'art'),
#   ('resultado', 'n'),
#   ('teria', 'v-fin'),
#   ('sido', 'v-pcp'),
#   ('outro', 'pron-det'),
#   ('.', '.')],
#  [('valtinho', 'prop'),
#   ('foi', 'v-fin'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('melhores', 'adj'),
#   ('jogadores', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('penafiel', 'prop'),
#   (',', ','),
#   ('este', 'pron-det'),
#   ('brasileiro', 'n'),
#   ('de', 'prp'),
#   ('pernas', 'n'),
#   ('altas', 'adj'),
#   ('.', '.')],
#  [('de', 'prp'),
#   ('os', 'art'),
#   ('seus', 'pron-det'),
#   ('pés', 'n'),
#   ('ainda', 'adv'),
#   ('nasceu', 'v-fin'),
#   ('alguma', 'pron-det'),
#   ('coisa', 'n'),
#   (',', ','),
#   ('embora', 'conj-s'),
#   ('o', 'art'),
#   ('resto', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('equipa', 'n'),
#   ('não', 'adv'),
#   ('ajudasse', 'v-fin'),
#   ('grande', 'adj'),
#   ('coisa', 'n'),
#   ('.', '.')],
#  [('lutou', 'v-fin'),
#   ('como', 'adv'),
#   ('lhe', 'pron-pers'),
#   ('vemos', 'v-fin'),
#   ('poucas', 'pron-det'),
#   ('vezes', 'n'),
#   ('e', 'conj-c'),
#   ('ainda', 'adv'),
#   ('teve', 'v-fin'),
#   ('em', 'prp'),
#   ('os', 'art'),
#   ('pés', 'n'),
#   ('uma', 'art'),
#   ('boa', 'adj'),
#   ('oportunidade', 'n'),
#   ('de', 'prp'),
#   ('golo', 'n'),
#   (',', ','),
#   ('mas', 'conj-c'),
#   ('teve', 'v-fin'),
#   ('que', 'conj-s'),
#   ('rematar', 'v-inf'),
#   ('em', 'prp'),
#   ('jeito', 'n'),
#   ('e', 'conj-c'),
#   ('não', 'adv'),
#   ('em', 'prp'),
#   ('força', 'n'),
#   (',', ','),
#   ('como', 'adv'),
#   ('gosta', 'v-fin'),
#   ('mais', 'adv'),
#   ('.', '.')],
#  [('a', 'prp'),
#   ('aumentar', 'v-inf'),
#   ('a', 'art'),
#   ('confusão', 'n'),
#   ('geral', 'adj'),
#   ('em', 'prp'),
#   ('os', 'art'),
#   ('meios', 'n'),
#   ('jornalísticos', 'adj'),
#   (',', ','),
#   ('chegou', 'v-fin'),
#   ('entretanto', 'adv'),
#   ('a', 'prp'),
#   ('as', 'art'),
#   ('redacções', 'n'),
#   ('um', 'art'),
#   ('outro', 'pron-det'),
#   ('fax', 'n'),
#   (',', ','),
#   ('este', 'pron-det'),
#   ('assinado', 'v-pcp'),
#   ('por', 'prp'),
#   ('o', 'art'),
#   ('deputado', 'n'),
#   ('pacheco_pereira', 'prop'),
#   (',', ','),
#   ('em', 'prp'),
#   ('que', 'pron-indp'),
#   ('se', 'pron-pers'),
#   ('afirma', 'v-fin'),
#   (';', ';')],
#  [('a', 'art'),
#   ('frase', 'n'),
#   ('que', 'pron-indp'),
#   ('o', 'art'),
#   ('senhor', 'n'),
#   ('primeiro-ministro', 'n'),
#   ('leu', 'v-fin'),
#   (',', ','),
#   ('não', 'adv'),
#   ('foi', 'v-fin'),
#   ('ele', 'pron-pers'),
#   ('.', '.')],
#  [('fui', 'v-fin'), ('eu', 'pron-pers'), ('.', '.'), ('»', '»')],
#  [('{', '{'),
#   ('há', 'v-fin'),
#   ('quem', 'pron-indp'),
#   ('defenda', 'v-fin'),
#   (',', ','),
#   ('no_entanto', 'adv'),
#   (',', ','),
#   ('que', 'conj-s'),
#   ('se', 'pron-pers'),
#   ('trata', 'v-fin'),
#   ('de', 'prp'),
#   ('um', 'art'),
#   ('fax', 'n'),
#   ('apócrifo', 'adj'),
#   (',', ','),
#   ('realmente', 'adv'),
#   ('escrito', 'v-pcp'),
#   ('por', 'prp'),
#   ('o', 'art'),
#   ('deputado', 'n'),
#   ('josé_magalhães', 'prop'),
#   (',', ','),
#   ('o_qual', 'pron-indp'),
#   ('teria', 'v-fin'),
#   (',', ','),
#   ('aliás', 'adv'),
#   (',', ','),
#   ('imitado', 'v-pcp'),
#   ('a', 'art'),
#   ('letra', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('ex-deputado', 'n'),
#   ('antónio_barreto', 'prop'),
#   ('.', '.')],
#  [('fontes', 'n'),
#   ('fidedignas', 'adj'),
#   ('que', 'pron-indp'),
#   ('o', 'art'),
#   ('mesmo', 'pron-det'),
#   ('é', 'v-fin'),
#   ('dizer', 'v-inf'),
#   (',', ','),
#   ('não', 'adv'),
#   ('jornalísticas', 'adj'),
#   ('garantiram', 'v-fin'),
#   ('entretanto', 'adv'),
#   ('que', 'conj-s'),
#   (',', ','),
#   ('entre', 'prp'),
#   ('as', 'art'),
#   ('frases', 'n'),
#   ('atribuídas', 'v-pcp'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('senhor', 'n'),
#   ('primeiro-ministro', 'n'),
#   ('que', 'pron-indp'),
#   (',', ','),
#   ('de', 'prp'),
#   ('facto', 'n'),
#   (',', ','),
#   ('lhe', 'pron-pers'),
#   ('não', 'adv'),
#   ('pertencem', 'v-fin'),
#   ('estão', 'v-fin'),
#   ('o', 'art'),
#   ('comentário', 'n'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('congresso', 'n'),
#   ('«', '«'),
#   ('portugal_e_o_futuro', 'prop'),
#   (',', ','),
#   ('a', 'art'),
#   ('resposta', 'n'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('deputado', 'n'),
#   ('adriano_moreira', 'prop'),
#   ('quando', 'adv'),
#   ('este', 'pron-det'),
#   ('o', 'pron-pers'),
#   ('interrogou', 'v-fin'),
#   ('sobre', 'prp'),
#   ('a', 'art'),
#   ('sua', 'pron-det'),
#   ('concepção', 'n'),
#   ('de', 'prp'),
#   ('federalismo', 'n'),
#   ('e', 'conj-c'),
#   ('até', 'adv'),
#   ('!', '!'),
#   ('a', 'art'),
#   ('contestada', 'v-pcp'),
#   ('frase', 'n'),
#   ('sobre', 'prp'),
#   ('a', 'art'),
#   ('fidedignidade', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('jornalistas', 'n'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('benfica', 'prop'),
#   ('voltou', 'v-fin'),
#   ('ontem', 'adv'),
#   ('a', 'prp'),
#   ('vencer', 'v-inf'),
#   ('o', 'art'),
#   ('lokomotiv_de_moscovo', 'prop'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('diferença', 'n'),
#   ('mínima', 'adj'),
#   ('{', '{'),
#   ('3-2', 'num'),
#   ('}', '}'),
#   (',', ','),
#   ('passando', 'v-ger'),
#   ('a', 'prp'),
#   ('os', 'art'),
#   ('quartos-de-final', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('taça_das_taças', 'prop'),
#   ('em', 'prp'),
#   ('futebol', 'n'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('jogo', 'n'),
#   ('chegou', 'v-fin'),
#   ('a', 'prp'),
#   ('estar', 'v-inf'),
#   ('complicado', 'v-pcp'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('equipa', 'n'),
#   ('de', 'prp'),
#   ('paulo_autuori', 'prop'),
#   (',', ','),
#   ('essencialmente', 'adv'),
#   ('porque', 'conj-s'),
#   ('o', 'art'),
#   ('lokomotiv', 'prop'),
#   ('marcou', 'v-fin'),
#   ('muito', 'adv'),
#   ('cedo', 'adv'),
#   ('{', '{'),
#   ("8'", 'num'),
#   ('}', '}'),
#   ('e', 'conj-c'),
#   ('os', 'art'),
#   ('jogadores', 'n'),
#   ('portugueses', 'adj'),
#   ('não', 'adv'),
#   ('conseguiam', 'v-fin'),
#   ('adaptar-', 'v-inf'),
#   ('se', 'pron-pers'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('estado', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('relvado', 'n'),
#   ('.', '.')],
#  [('mas', 'conj-c'),
#   ('a', 'art'),
#   ('expulsão', 'n'),
#   ('prematura', 'adj'),
#   ('e', 'conj-c'),
#   ('estúpida', 'adj'),
#   ('de', 'prp'),
#   ('gurenko', 'prop'),
#   (',', ','),
#   ('quando', 'adv'),
#   ('ainda', 'adv'),
#   ('não', 'adv'),
#   ('estava', 'v-fin'),
#   ('decorrida', 'v-pcp'),
#   ('meia_hora', 'n'),
#   ('de', 'prp'),
#   ('jogo', 'n'),
#   (',', ','),
#   ('seguida', 'v-pcp'),
#   (',', ','),
#   ('pouco', 'adv'),
#   ('depois', 'adv'),
#   (',', ','),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('entrada', 'n'),
#   ('de', 'prp'),
#   ('panduru', 'prop'),
#   (',', ','),
#   ('foi', 'v-fin'),
#   ('o', 'art'),
#   ('suficiente', 'n'),
#   ('para', 'prp'),
#   ('dar', 'v-inf'),
#   ('a', 'art'),
#   ('volta', 'n'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('resultado', 'n'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('benfica', 'prop'),
#   ('apresentou', 'v-fin'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('esquema', 'n'),
#   ('habitual', 'adj'),
#   (',', ','),
#   ('com', 'prp'),
#   ('jamir', 'prop'),
#   ('e', 'conj-c'),
#   ('tahar', 'prop'),
#   ('mais', 'adv'),
#   ('recuados', 'v-pcp'),
#   ('e', 'conj-c'),
#   ('insistindo', 'v-ger'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('utilização', 'n'),
#   ('de', 'prp'),
#   ('valdo', 'prop'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('esquerda', 'n'),
#   ('.', '.')],
#  [('em_contrapartida', 'pp'),
#   (',', ','),
#   ('o', 'art'),
#   ('lokomotiv', 'prop'),
#   ('actuava', 'v-fin'),
#   ('com', 'prp'),
#   ('três', 'num'),
#   ('centrais', 'n'),
#   (',', ','),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('líbero', 'n'),
#   ('chugainov', 'prop'),
#   (',', ','),
#   ('como', 'prp'),
#   ('habitualmente', 'adv'),
#   (',', ','),
#   ('a', 'prp'),
#   ('comandar', 'v-inf'),
#   ('o', 'art'),
#   ('jogo', 'n'),
#   ('e', 'conj-c'),
#   ('o', 'art'),
#   ('lateral-esquerdo', 'n'),
#   ('solomatin', 'prop'),
#   ('muito', 'adv'),
#   ('activo', 'adj'),
#   ('.', '.')],
#  [('muito', 'adv'),
#   ('bem', 'adv'),
#   ('estavam', 'v-fin'),
#   ('também', 'adv'),
#   ('os', 'art'),
#   ('três', 'num'),
#   ('médios', 'n'),
#   ('maminov', 'prop'),
#   (',', ','),
#   ('drozdov', 'prop'),
#   ('e', 'conj-c'),
#   ('kharlachev', 'prop'),
#   (',', ','),
#   ('desempenhando', 'v-ger'),
#   ('kosolapov', 'prop'),
#   ('as', 'art'),
#   ('funções', 'n'),
#   ('de', 'prp'),
#   ('«', '«'),
#   ('pivot', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('ataque', 'n'),
#   ('.', '.')],
#  [('por', 'prp'),
#   ('isso', 'pron-indp'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('também', 'adv'),
#   ('porque', 'conj-s'),
#   ('os', 'art'),
#   ('russos', 'n'),
#   ('estavam', 'v-fin'),
#   ('mais', 'adv'),
#   ('bem', 'adv'),
#   ('adaptados', 'v-pcp'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('muito', 'adv'),
#   ('enlameado', 'v-pcp'),
#   ('e', 'conj-c'),
#   ('escorregadio', 'adj'),
#   ('relvado', 'n'),
#   (',', ','),
#   ('o', 'art'),
#   ('lokomotiv', 'prop'),
#   ('era', 'v-fin'),
#   ('mais', 'adv'),
#   ('rápido', 'adj'),
#   ('sobre', 'prp'),
#   ('a', 'art'),
#   ('bola', 'n'),
#   (',', ','),
#   ('ganhando', 'v-ger'),
#   ('a', 'art'),
#   ('maior', 'adj'),
#   ('parte', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('duelos', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('zona', 'n'),
#   ('fulcral', 'adj'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('terreno', 'n'),
#   (',', ','),
#   ('situada', 'v-pcp'),
#   ('entre', 'prp'),
#   ('o', 'art'),
#   ('meio-campo', 'n'),
#   ('e', 'conj-c'),
#   ('a', 'art'),
#   ('defesa', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('benfica', 'prop'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('«', '«'),
#   ('cocktail', 'n'),
#   ('que', 'pron-indp'),
#   ('juppé', 'prop'),
#   ('condena', 'v-fin'),
#   ('é', 'v-fin'),
#   ('bem', 'adv'),
#   ('real', 'adj'),
#   ('.', '.')],
#  [('mas', 'conj-c'),
#   ('é-', 'v-fin'),
#   ('o', 'pron-pers'),
#   ('apenas', 'adv'),
#   ('porque', 'conj-s'),
#   ('este', 'pron-det'),
#   ('governo', 'prop'),
#   ('e', 'conj-c'),
#   ('esta', 'pron-det'),
#   ('maioria', 'n'),
#   (',', ','),
#   ('escolheram', 'v-fin'),
#   (',', ','),
#   ('desde', 'prp'),
#   ('agosto', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('ano', 'n'),
#   ('passado', 'v-pcp'),
#   (',', ','),
#   ('a', 'art'),
#   ('imigração', 'n'),
#   ('e', 'conj-c'),
#   ('a', 'art'),
#   ('política', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('imigração', 'n'),
#   ('como', 'adv'),
#   ('ponto', 'n'),
#   ('de', 'prp'),
#   ('clivagem', 'n'),
#   ('política', 'adj'),
#   ('para', 'prp'),
#   ('as', 'art'),
#   ('próximas', 'adj'),
#   ('legislativas', 'adj'),
#   (',', ','),
#   ('ontem', 'adv'),
#   ('mesmo', 'adv'),
#   ('marcadas', 'v-pcp'),
#   ('para', 'prp'),
#   ('março', 'n'),
#   ('de', 'prp'),
#   ('1998', 'num'),
#   (',', ','),
#   ('em', 'prp'),
#   ('simultâneo', 'adj'),
#   ('com', 'prp'),
#   ('as', 'art'),
#   ('regionais', 'adj'),
#   ('.', '.')],
#  [('um', 'art'),
#   ('endurecimento', 'n'),
#   ('nítido', 'adj'),
#   ('existe', 'v-fin'),
#   ('desde_então', 'adv'),
#   ('em', 'prp'),
#   ('este', 'pron-det'),
#   ('terreno', 'n'),
#   ('altamente', 'adv'),
#   ('perigoso', 'adj'),
#   ('.', '.')],
#  [('e', 'conj-c'),
#   ('razão', 'n'),
#   ('de', 'prp'),
#   ('esta', 'pron-det'),
#   ('escolha', 'n'),
#   ('é', 'v-fin'),
#   (',', ','),
#   ('obviamente', 'adv'),
#   (',', ','),
#   ('a', 'art'),
#   ('progressão', 'n'),
#   ('demente', 'adj'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('frente_nacional', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('prospera', 'v-fin'),
#   ('sempre', 'adv'),
#   ('a', 'prp'),
#   ('apontar', 'v-inf'),
#   ('o', 'art'),
#   ('imigrante', 'n'),
#   ('como', 'adv'),
#   ('bode_expiatório', 'n'),
#   ('e', 'conj-c'),
#   ('simultaneamente', 'adv'),
#   ('como', 'adv'),
#   ('a', 'art'),
#   ('fonte', 'n'),
#   ('de', 'prp'),
#   ('todos', 'pron-det'),
#   ('os', 'art'),
#   ('males', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('povo', 'n'),
#   ('francês', 'adj'),
#   ('.', '.')],
#  [('surpresa', 'n'),
#   ('e', 'conj-c'),
#   ('sugestões', 'n'),
#   ('para', 'prp'),
#   ('o', 'art'),
#   ('futuro', 'n')],
#  [('foi', 'adv'),
#   ('com', 'prp'),
#   ('estupefacção', 'n'),
#   ('e', 'conj-c'),
#   ('surpresa', 'n'),
#   ('que', 'adv'),
#   ('li', 'v-fin'),
#   (',', ','),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('edição', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('passado', 'v-pcp'),
#   ('fim-de-semana', 'n'),
#   (',', ','),
#   ('os', 'art'),
#   ('comunicados', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('direcção', 'n'),
#   ('e', 'conj-c'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('administração', 'n'),
#   ('de', 'prp'),
#   ('este', 'pron-det'),
#   ('jornal', 'n'),
#   ('.', '.')],
#  [('sou', 'v-fin'),
#   ('um', 'art'),
#   ('leitor', 'n'),
#   ('assíduo', 'adj'),
#   ('e', 'conj-c'),
#   ('atento', 'adj'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('público', 'prop'),
#   (',', ','),
#   ('desde', 'prp'),
#   ('o', 'art'),
#   ('primeiro', 'adj'),
#   ('número', 'n'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('não', 'adv'),
#   ('poucas', 'pron-det'),
#   ('vezes', 'n'),
#   ('tenho', 'v-fin'),
#   ('manifestado', 'v-pcp'),
#   ('opiniões', 'n'),
#   ('em', 'prp'),
#   ('as', 'art'),
#   ('suas', 'pron-det'),
#   ('páginas', 'n'),
#   (',', ','),
#   ('o_que', 'pron-indp'),
#   ('me', 'pron-pers'),
#   ('leva', 'v-fin'),
#   ('agora', 'adv'),
#   ('a', 'prp'),
#   ('emitir', 'v-inf'),
#   ('o', 'art'),
#   ('meu', 'pron-det'),
#   ('pensamento', 'n'),
#   ('sobre', 'prp'),
#   ('o', 'art'),
#   ('jornal', 'n'),
#   (',', ','),
#   ('sobre', 'prp'),
#   ('quem', 'pron-indp'),
#   ('o', 'pron-pers'),
#   ('faz', 'v-fin'),
#   ('e', 'conj-c'),
#   ('sobre', 'prp'),
#   ('os', 'art'),
#   ('ditos', 'adj'),
#   ('comunicados', 'n'),
#   ('.', '.')],
#  [('1.', 'num'),
#   ('o', 'art'),
#   ('público', 'prop'),
#   ('veio', 'v-fin'),
#   ('dar', 'v-pcp'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('imprensa', 'n'),
#   ('diária', 'adj'),
#   ('portuguesa', 'n'),
#   ('uma', 'art'),
#   ('nova', 'adj'),
#   ('dimensão', 'n'),
#   ('e', 'conj-c'),
#   (',', ','),
#   ('por', 'prp'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('aparecimento', 'n'),
#   (',', ','),
#   ('obrigou', 'v-fin'),
#   ('os', 'art'),
#   ('«', '«'),
#   ('grandes', 'adj'),
#   ('{', '{'),
#   ('«', '«'),
#   ('jn', 'prop'),
#   ('e', 'conj-c'),
#   ('«', '«'),
#   ('dn', 'prop'),
#   ('}', '}'),
#   ('a', 'prp'),
#   ('reformular', 'v-inf'),
#   ('a', 'art'),
#   ('sua', 'pron-det'),
#   ('postura', 'n'),
#   ('e', 'conj-c'),
#   ('também', 'adv'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('grafismo', 'n'),
#   ('.', '.')],
#  [('concertos', 'n'),
#   ('em', 'prp'),
#   ('mi', 'n'),
#   ('menor', 'adj'),
#   (',', ','),
#   ('rv', 'prop'),
#   ('277', 'num'),
#   ('{', '{'),
#   ('«', '«'),
#   ('il_favorito', 'prop'),
#   ('}', '}'),
#   (',', ','),
#   ('em', 'prp'),
#   ('mi', 'n'),
#   ('bemol', 'n'),
#   (',', ','),
#   ('rv', 'prop'),
#   ('253', 'num'),
#   ('{', '{'),
#   ('«', '«'),
#   ('la_tempesta_di_mare', 'prop'),
#   ('}', '}'),
#   (',', ','),
#   ('em', 'prp'),
#   ('lá', 'n'),
#   ('maior', 'adj'),
#   (',', ','),
#   ('rv', 'prop'),
#   ('353', 'num'),
#   (',', ','),
#   ('em', 'prp'),
#   ('mi', 'n'),
#   ('maior', 'adj'),
#   (',', ','),
#   ('rv', 'prop'),
#   ('271', 'num'),
#   ('{', '{'),
#   ('«', '«'),
#   ("l'amoroso", 'n'),
#   ('}', '}')],
#  [('london_vivaldi_orchestra', 'prop'),
#   ('{', '{'),
#   ('1984', 'num'),
#   ('}', '}')],
#  [('tal_como', 'adv'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('última', 'adj'),
#   ('final', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('campeonato_do_mundo', 'prop'),
#   (',', ','),
#   ('disputada', 'v-pcp'),
#   ('em', 'prp'),
#   ('nova_iorque', 'prop'),
#   ('e', 'conj-c'),
#   ('lion', 'prop'),
#   (',', ','),
#   ('kasparov', 'prop'),
#   ('tenta', 'v-fin'),
#   ('apresentar-', 'v-inf'),
#   ('se', 'pron-pers'),
#   ('como', 'adv'),
#   ('o', 'art'),
#   ('«', '«'),
#   ('bom', 'adj'),
#   ('reformador', 'n'),
#   ('contra', 'prp'),
#   ('o', 'art'),
#   ('«', '«'),
#   ('mau', 'adj'),
#   ('conservador', 'n'),
#   ('{', '{'),
#   ('karpov', 'prop'),
#   ('}', '}'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('fide', 'prop'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('organiza', 'v-fin'),
#   ('a', 'art'),
#   ('competição', 'n'),
#   ('desde', 'prp'),
#   ('1948', 'num'),
#   (',', ','),
#   ('declarou', 'v-fin'),
#   ('estar', 'v-inf'),
#   ('pronta', 'adj'),
#   ('para', 'prp'),
#   ('defender', 'v-inf'),
#   ('os', 'art'),
#   ('seus', 'pron-det'),
#   ('direitos', 'n'),
#   ('em', 'prp'),
#   ('tribunal', 'n'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('acusou', 'v-fin'),
#   ('kasparov', 'prop'),
#   ('e', 'conj-c'),
#   ('short', 'prop'),
#   ('de', 'prp'),
#   ('privilegiarem', 'v-inf'),
#   ('os', 'art'),
#   ('seus', 'pron-det'),
#   ('interesses', 'n'),
#   ('económicos', 'adj'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('tentarem', 'v-inf'),
#   ('conseguir', 'v-inf'),
#   ('uma', 'art'),
#   ('verba', 'n'),
#   ('superior', 'adj'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('oferecida', 'v-pcp'),
#   ('por', 'prp'),
#   ('a', 'art'),
#   ('cidade', 'n'),
#   ('de', 'prp'),
#   ('manchester', 'prop'),
#   ('para', 'prp'),
#   ('organizar', 'v-inf'),
#   ('a', 'art'),
#   ('final', 'n'),
#   ('e', 'conj-c'),
#   ('que', 'pron-indp'),
#   ('rondava', 'v-fin'),
#   ('os', 'art'),
#   ('250', 'num'),
#   ('mil', 'num'),
#   ('contos', 'n'),
#   ('.', '.')],
#  [('este', 'pron-det'),
#   ('«', '«'),
#   ('golpe_de_estado', 'n'),
#   ('deixa', 'v-fin'),
#   ('céptica', 'adj'),
#   ('a', 'art'),
#   ('maior', 'adj'),
#   ('parte', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('grandes', 'adj'),
#   ('mestres', 'n'),
#   ('de', 'prp'),
#   ('xadrez', 'n'),
#   ('{', '{'),
#   ('cerca_de', 'adv'),
#   ('300', 'num'),
#   ('em', 'prp'),
#   ('todo', 'pron-indp'),
#   ('o', 'art'),
#   ('mundo', 'n'),
#   ('}', '}'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('esperam', 'v-fin'),
#   ('ver', 'v-inf'),
#   ('a', 'art'),
#   ('situação', 'n'),
#   ('clarificada', 'v-pcp'),
#   (',', ','),
#   ('independentemente', 'adv'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('parte', 'n'),
#   ('que', 'pron-indp'),
#   ('acabe', 'v-fin'),
#   ('vencedora', 'adj'),
#   ('.', '.')],
#  [('por_outro_lado', 'pp'),
#   (',', ','),
#   ('a', 'art'),
#   ('expulsão', 'n'),
#   ('de', 'prp'),
#   ('kasparov', 'prop'),
#   (',', ','),
#   ('detentor', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('título', 'n'),
#   ('mundial', 'adj'),
#   ('desde', 'prp'),
#   ('1985', 'num'),
#   (',', ','),
#   ('criará', 'v-fin'),
#   ('dificuldades', 'n'),
#   ('a', 'prp'),
#   ('a', 'art'),
#   ('fide', 'prop'),
#   ('para', 'prp'),
#   ('convencer', 'v-inf'),
#   ('manchester', 'prop'),
#   ('a', 'prp'),
#   ('acolher', 'v-inf'),
#   ('uma', 'art'),
#   ('falsa', 'adj'),
#   ('final', 'n'),
#   ('entre', 'prp'),
#   ('karpov', 'prop'),
#   ('e', 'conj-c'),
#   ('timman', 'prop'),
#   ('.', '.')],
#  [('isto', 'pron-indp'),
# ...
#   ('a', 'prp'),
#   ('viseu', 'prop'),
#   ('por', 'prp'),
#   ('3-1', 'num'),
#   ('e', 'conj-c'),
#   ('está', 'v-fin'),
#   ('a', 'prp'),
#   ('repetir', 'v-inf'),
#   ('a', 'art'),
#   ('má', 'adj'),
#   ('campanha', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('temporada', 'n'),
#   ('anterior', 'adj'),
#   ('.', '.')],
#  [('em', 'prp'),
#   ('os', 'art'),
#   ('restantes', 'adj'),
#   ('encontros', 'n'),
#   (',', ','),
#   ('o', 'art'),
#   ('torrense', 'prop'),
#   ('foi', 'v-fin'),
#   ('garantir', 'v-inf'),
#   ('o', 'art'),
#   ('empate', 'n'),
#   ('{', '{'),
#   ('0-0', 'num'),
#   ('}', '}'),
#   ('em', 'prp'),
#   ('matosinhos', 'prop'),
#   ('perante', 'prp'),
#   ('o', 'art'),
#   ('leixões', 'prop'),
#   (',', ','),
#   ('enquanto', 'adv'),
#   ('as', 'art'),
#   ('vitórias', 'n'),
#   ('tangenciais', 'adj'),
#   ('{', '{'),
#   ('1-0', 'num'),
#   ('}', '}'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('união_de_leiria', 'prop'),
#   ('sobre', 'prp'),
#   ('o', 'art'),
#   ('leça', 'prop'),
#   ('e', 'conj-c'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('chaves', 'prop'),
#   ('contra', 'prp'),
#   ('o', 'art'),
#   ('felgueiras', 'prop'),
#   (',', ','),
#   ('vieram', 'v-fin'),
#   ('elevar', 'v-inf'),
#   ('para', 'prp'),
#   ('22', 'num'),
#   ('os', 'art'),
#   ('golos', 'n'),
#   ('marcados', 'v-pcp'),
#   ('em', 'prp'),
#   ('esta', 'pron-det'),
#   ('8ª', 'adj'),
#   ('jornada', 'n'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('forneceu', 'v-fin'),
#   ('quatro', 'num'),
#   ('vitórias', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('visitados', 'v-pcp'),
#   (',', ','),
#   ('quatro', 'num'),
#   ('empates', 'n'),
#   ('e', 'conj-c'),
#   ('apenas', 'adv'),
#   ('uma', 'num'),
#   ('vitória', 'n'),
#   ('fora', 'adv'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('escudo', 'n'),
#   ('esteve', 'v-fin'),
#   ('bastante', 'adv'),
#   ('pressionado', 'v-pcp'),
#   (',', ','),
#   ('devido', 'v-pcp'),
#   ('sobretudo', 'adv'),
#   ('a', 'prp'),
#   ('vendas', 'n'),
#   ('especulativas', 'adj'),
#   ('por_parte_de', 'prp'),
#   ('bancos', 'n'),
#   ('estrangeiros', 'adj'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('as', 'art'),
#   ('frequentes', 'adj'),
#   ('intervenções', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('banco_de_portugal', 'prop'),
#   ('apresentaram-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('eficazes', 'adj'),
#   (',', ','),
#   ('quebrando', 'v-ger'),
#   ('a', 'art'),
#   ('tendência', 'n'),
#   ('de', 'prp'),
#   ('queda', 'n'),
#   (',', ','),
#   ('por_vezes', 'pp'),
#   ('acentuada', 'v-pcp'),
#   (',', ','),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('divisa', 'n'),
#   ('nacional', 'adj'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('peseta', 'n'),
#   ('manteve-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('topo', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('mecanismo', 'n'),
#   ('de', 'prp'),
#   ('taxas', 'n'),
#   ('de', 'prp'),
#   ('câmbio', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('sme', 'n')],
#  [('r.', 'n'),
#   ('era', 'v-fin'),
#   ('o', 'art'),
#   ('meu', 'pron-det'),
#   ('ano', 'n'),
#   ('de', 'prp'),
#   ('agregação', 'n'),
#   ('em', 'prp'),
#   ('filosofia', 'prop'),
#   (';', ';'),
#   ('concluí-', 'v-fin'),
#   ('a', 'pron-pers'),
#   ('em', 'prp'),
#   ('esse', 'pron-det'),
#   ('mês', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('sorbonne', 'prop'),
#   ('comentando', 'v-ger'),
#   ('uma', 'art'),
#   ('frase', 'n'),
#   ('de', 'prp'),
#   ('einstein', 'prop'),
#   ('sobre', 'prp'),
#   ('a', 'art'),
#   ('compreensibilidade', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('mundo', 'n'),
#   ('.', '.')],
#  [('mas', 'conj-c'),
#   ('nunca', 'adv'),
#   ('fui', 'v-fin'),
#   ('um', 'art'),
#   ('dirigente', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('movimento', 'n'),
#   (',', ','),
#   ('apenas', 'adv'),
#   ('um', 'num'),
#   ('simples', 'adj'),
#   ('peão', 'n'),
#   ('.', '.')],
#  [('tenho', 'v-fin'),
#   ('46', 'num'),
#   ('anos', 'n'),
#   (',', ','),
#   ('ou_seja', 'adv'),
#   (',', ','),
#   ('pertenço', 'v-fin'),
#   ('exactamente', 'adv'),
#   ('a', 'prp'),
#   ('essa', 'pron-det'),
#   ('geração', 'n'),
#   (',', ','),
#   ('facto', 'n'),
#   ('de', 'prp'),
#   ('que', 'pron-indp'),
#   ('me', 'pron-pers'),
#   ('orgulho', 'v-fin'),
#   ('muito', 'adv'),
#   ('.', '.')],
#  [('penso', 'v-fin'),
#   ('que', 'conj-s'),
#   ('em_relação_a', 'prp'),
#   ('as', 'art'),
#   ('minhas', 'pron-det'),
#   ('filhas', 'n'),
#   (',', ','),
#   ('que', 'pron-indp'),
#   ('têm', 'v-fin'),
#   ('hoje', 'adv'),
#   ('23', 'num'),
#   ('e', 'conj-c'),
#   ('20', 'num'),
#   ('anos', 'n'),
#   (',', ','),
#   ('tive', 'v-fin'),
#   ('muito', 'adv'),
#   ('mais', 'pron-det'),
#   ('sorte', 'n'),
#   (',', ','),
#   ('apesar_de', 'prp'),
#   ('ter', 'v-inf'),
#   ('crescido', 'v-pcp'),
#   ('em', 'prp'),
#   ('uma', 'art'),
#   ('sociedade', 'n'),
#   ('que', 'pron-indp'),
#   ('era', 'v-fin'),
#   ('certamente', 'adv'),
#   ('mais', 'adv'),
#   ('autoritária', 'adj'),
#   ('que', 'conj-s'),
#   ('a', 'pron-det'),
#   ('de', 'prp'),
#   ('elas', 'pron-pers'),
#   ('.', '.')],
#  [('as', 'art'),
#   ('relações', 'n'),
#   ('entre', 'prp'),
#   ('pais', 'n'),
#   ('e', 'conj-c'),
#   ('filhos', 'n'),
#   ('são', 'v-fin'),
#   ('hoje', 'adv'),
#   ('de', 'prp'),
#   ('melhor', 'adj'),
#   ('qualidade', 'n'),
#   ('.', '.')],
#  [('p.', 'n'),
#   ('as', 'art'),
#   ('suas', 'pron-det'),
#   ('filhas', 'n'),
#   ('compreendem', 'v-fin'),
#   ('o_que', 'pron-indp'),
#   ('se', 'pron-pers'),
#   ('passou', 'v-fin'),
#   ('em', 'prp'),
#   ('maio', 'n'),
#   ('68', 'num'),
#   ('?', '?')],
#  [('compreendem', 'v-fin'),
#   ('o_que', 'pron-indp'),
#   ('é_que', 'adv'),
#   ('vocês', 'pron-pers'),
#   ('queriam', 'v-fin'),
#   ('?', '?')],
#  [('enviado_especial', 'prop'),
#   (',', ','),
#   ('rtp', 'prop'),
#   ('1', 'num'),
#   (',', ','),
#   ('com', 'prp'),
#   ('os', 'art'),
#   ('mineiros', 'n'),
#   ('portugueses', 'adj'),
#   ('de', 'prp'),
#   ('espanha', 'prop')],
#  [('filões', 'n'), ('de', 'prp'), ('a', 'art'), ('morte', 'n')],
#  [('em', 'prp'),
#   ('o', 'art'),
#   ('momento', 'n'),
#   ('em', 'prp'),
#   ('que', 'pron-indp'),
#   ('a', 'art'),
#   ('união_europeia', 'prop'),
#   ('decidiu', 'v-fin'),
#   ('abandonar', 'v-inf'),
#   ('a', 'art'),
#   ('exploração', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('carvão_de_pedra', 'n'),
#   (',', ','),
#   ('existem', 'v-fin'),
#   ('cinco', 'num'),
#   ('mil', 'num'),
#   ('mineiros', 'n'),
#   ('portugueses', 'adj'),
#   ('em', 'prp-'),
#   ('o', 'art'),
#   ('norte_de_espanha', 'prop'),
#   (',', ','),
#   ('em', 'prp'),
#   ('as', 'art'),
#   ('províncias', 'n'),
#   ('de', 'prp'),
#   ('león', 'prop'),
#   ('e', 'conj-c'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('astúrias', 'prop'),
#   (',', ','),
#   ('condenados', 'v-pcp'),
#   ('a', 'prp'),
#   ('assistir', 'v-inf'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('encerramento', 'n'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('minas', 'n'),
#   ('onde', 'adv'),
#   ('trabalham', 'v-fin'),
#   ('.', '.')],
#  [('partiram', 'v-fin'),
#   ('para', 'prp'),
#   ('um', 'art'),
#   ('el_dorado', 'prop'),
#   (',', ','),
#   ('deparam-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('agora', 'adv'),
#   ('com', 'prp'),
#   ('a', 'art'),
#   ('perspectiva', 'n'),
#   ('de', 'prp'),
#   ('uma', 'art'),
#   ('reforma', 'n'),
#   ('antecipada', 'v-pcp'),
#   ('ou', 'conj-c'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('desemprego', 'n'),
#   ('forçado', 'v-pcp'),
#   ('.', '.')],
#  [('a', 'art'),
#   ('ue', 'prop'),
#   ('é', 'v-fin'),
#   ('o', 'art'),
#   ('principal', 'adj'),
#   ('parceiro', 'n'),
#   ('comercial', 'adj'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('rússia', 'prop'),
#   (',', ','),
#   ('representando', 'v-ger'),
#   ('37', 'num'),
#   ('por_cento', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('total', 'n'),
#   ('de', 'prp'),
#   ('as', 'art'),
#   ('trocas', 'n'),
#   ('comerciais', 'adj'),
#   ('contra', 'prp'),
#   ('24', 'num'),
#   ('por_cento', 'n'),
#   ('no_caso_de', 'prp'),
#   ('as', 'art'),
#   ('restantes', 'adj'),
#   ('ex-repúblicas', 'n'),
#   ('soviéticas', 'adj'),
#   (',', ','),
#   ('ou', 'conj-c'),
#   ('quatro', 'num'),
#   ('por_cento', 'n'),
#   ('com', 'prp'),
#   ('os', 'art'),
#   ('estados_unidos', 'prop'),
#   ('.', '.')],
#  [('com', 'prp'),
#   ('exportações', 'n'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('ue', 'prop'),
#   ('de', 'prp'),
#   ('15,5', 'num'),
#   ('mil', 'num'),
#   ('milhões', 'n'),
#   ('de', 'prp'),
#   ('ecus', 'n'),
#   ('e', 'conj-c'),
#   ('importando', 'v-ger'),
#   ('o', 'art'),
#   ('equivalente', 'adj'),
#   ('a', 'prp'),
#   ('11,5', 'num'),
#   ('mil', 'num'),
#   ('milhões', 'n'),
#   (',', ','),
#   ('a', 'art'),
#   ('rússia', 'prop'),
#   ('mantinha', 'v-fin'),
#   ('em', 'prp'),
#   ('1993', 'num'),
#   ('um', 'num'),
#   ('excedente', 'n'),
#   ('comercial', 'adj'),
#   (',', ','),
#   ('face_a', 'prp'),
#   ('os', 'art'),
#   ('europeus', 'n'),
#   (',', ','),
#   ('de', 'prp'),
#   ('quatro', 'num'),
#   ('mil', 'num'),
#   ('milhões', 'n'),
#   ('de', 'prp'),
#   ('ecus', 'n'),
#   ('.', '.')],
#  [('não', 'adv'),
#   ('é', 'v-fin'),
#   ('de', 'prp'),
#   ('estranhar', 'v-inf'),
#   (',', ','),
#   ('porque', 'conj-s'),
#   ('entre', 'prp'),
#   ('os', 'art'),
#   ('comensais', 'n'),
#   ('reunidos', 'v-pcp'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('dia', 'n'),
#   ('29', 'num'),
#   ('de', 'prp'),
#   ('agosto', 'n'),
#   ('em', 'prp'),
#   ('casa', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('romancista', 'n'),
#   ('norte-americano', 'adj'),
#   ('william_styron', 'prop'),
#   (',', ','),
#   ('prémio', 'n'),
#   ('pulitzer', 'prop'),
#   (',', ','),
#   ('em', 'prp'),
#   ("martha's_vineyard", 'prop'),
#   (',', ','),
#   ('uma', 'art'),
#   ('ilha', 'n'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('sul', 'n'),
#   ('de', 'prp'),
#   ('boston', 'prop'),
#   (',', ','),
#   ('massachusetts', 'prop'),
#   (',', ','),
#   ('não', 'adv'),
#   ('se', 'pron-pers'),
#   ('encontrava', 'v-fin'),
#   ('apenas', 'adv'),
#   ('o', 'art'),
#   ('presidente', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('estados_unidos', 'prop'),
#   (',', ','),
#   ('mas', 'conj-c'),
#   ('sobretudo', 'adv'),
#   ('esses', 'pron-det'),
#   ('dois', 'num'),
#   ('grandes', 'adj'),
#   ('obcecados', 'v-pcp'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('livros', 'n'),
#   ('que', 'pron-indp'),
#   ('são', 'v-fin'),
#   ('o', 'art'),
#   ('nobel', 'n'),
#   ('colombiano', 'adj'),
#   ('gabriel_garcía_márquez', 'prop'),
#   ('e', 'conj-c'),
#   ('o', 'art'),
#   ('mexicano', 'n'),
#   ('carlos_fuentes', 'prop'),
#   (',', ','),
#   ('último', 'adj'),
#   ('prémio', 'n'),
#   ('príncipe_das_astúrias_de_literatura', 'prop'),
#   ('.', '.')],
#  [('toda_a_gente', 'pron-indp'),
#   ('acreditou', 'v-fin'),
#   ('que', 'conj-s'),
#   ('essa', 'pron-det'),
#   ('reunião', 'n'),
#   (',', ','),
#   ('realizada', 'v-pcp'),
#   ('em', 'prp'),
#   ('plena', 'adj'),
#   ('crise', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('«', '«'),
#   ('balseros', 'n'),
#   ('»', '»'),
#   ('cubanos', 'adj'),
#   (',', ','),
#   ('tinha', 'v-fin'),
#   ('sido', 'v-pcp'),
#   ('programada', 'v-pcp'),
#   ('para', 'prp'),
#   ('falar', 'v-inf'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('nova', 'adj'),
#   ('crise', 'n'),
#   ('aberta', 'v-pcp'),
#   ('entre', 'prp'),
#   ('cuba', 'prop'),
#   ('e', 'conj-c'),
#   ('os', 'art'),
#   ('estados_unidos', 'prop'),
#   ('e', 'conj-c'),
#   (',', ','),
#   ('dada', 'v-pcp'),
#   ('a', 'art'),
#   ('personalidade', 'n'),
#   ('de', 'prp'),
#   ('os', 'art'),
#   ('convivas', 'n'),
#   ('garcía_márquez', 'prop'),
#   ('tem', 'v-fin'),
#   ('uma', 'art'),
#   ('relação', 'n'),
#   ('estreita', 'adj'),
#   ('com', 'prp'),
#   ('castro', 'prop'),
#   ('e', 'conj-c'),
#   ('fuentes', 'prop'),
#   ('defende', 'v-fin'),
#   ('o', 'art'),
#   ('fim', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('embargo', 'n'),
#   ('norte-americano', 'adj'),
#   ('para', 'prp'),
#   ('que', 'conj-s'),
#   ('se', 'pron-pers'),
#   ('inicie', 'v-fin'),
#   ('uma', 'art'),
#   ('nova', 'adj'),
#   ('etapa', 'n'),
#   ('em', 'prp'),
#   ('o', 'art'),
#   ('longo', 'adj'),
#   ('contencioso', 'adj'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('ilha', 'n'),
#   ('caraíba', 'adj'),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('poderoso', 'adj'),
#   ('vizinho', 'n'),
#   (',', ','),
#   ('deu-', 'v-fin'),
#   ('se', 'pron-pers'),
#   ('como', 'adv'),
#   ('ponto', 'n'),
#   ('assente', 'adj'),
#   ('que', 'conj-s'),
#   ('cuba', 'prop'),
#   ('tinha', 'v-fin'),
#   ('de', 'prp'),
#   ('ter', 'v-inf'),
#   ('sido', 'v-pcp'),
#   ('«', '«'),
#   ('o', 'art'),
#   ('»', '»'),
#   ('assunto', 'n'),
#   ('.', '.')],
#  [('a', 'prp'),
#   ('o', 'art'),
#   ('conseguir', 'v-inf'),
#   ('o', 'art'),
#   ('quinto', 'adj'),
#   ('tempo', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('«', '«'),
#   ('super', 'adj'),
#   ('pole', 'n'),
#   ('»', '»'),
#   (',', ','),
#   ('com', 'prp'),
#   ('1m', 'n'),
#   ('14', 'num'),
#   (',', ','),
#   ('511', 'num'),
#   ('s', 'n'),
#   (',', ','),
#   ('amorim', 'prop'),
#   ('ficou', 'v-fin'),
#   ('a', 'prp'),
#   ('836', 'num'),
#   ('milésimos', 'n'),
#   ('de', 'prp'),
#   ('segundo', 'adj'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('«', '«'),
#   ('pole_position', 'n'),
#   ('»', '»'),
#   ('de', 'prp'),
#   ('fabrizio_giovanardi', 'prop'),
#   (',', ','),
#   ('em', 'prp'),
#   ('alfa_romeo', 'prop'),
#   ('155', 'num'),
#   (',', ','),
#   ('e', 'conj-c'),
#   ('vai', 'v-fin'),
#   ('partir', 'v-inf'),
#   ('hoje', 'adv'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('terceira', 'adj'),
#   ('linha', 'n'),
#   ('de', 'prp'),
#   ('a', 'art'),
#   ('grelha', 'n'),
#   ('de', 'prp'),
#   ('partida', 'n'),
#   (',', ','),
#   ('depositando', 'v-ger'),
#   ('grandes', 'adj'),
#   ('esperanças', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('corrida', 'n'),
#   (';', ';')],
#  [('«', '«'),
#   ('o', 'art'),
#   ('carro', 'n'),
#   ('está', 'v-fin'),
#   ('bem', 'adv'),
#   ('equilibrado', 'v-pcp'),
#   ('e', 'conj-c'),
#   ('estamos', 'v-fin'),
#   ('esperançados', 'v-pcp'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('corrida', 'n'),
#   ('»', '»'),
#   ('.', '.')],
#  [('amorim', 'prop'),
#   ('ainda', 'adv'),
#   ('tentou', 'v-fin'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('«', '«'),
#   ('super_pole', 'n'),
#   ('»', '»'),
#   ('um', 'art'),
#   ('melhor', 'adj'),
#   ('resultado', 'n'),
#   (',', ','),
#   ('mas', 'conj-c'),
#   ('cometeu', 'v-fin'),
#   ('um', 'art'),
#   ('excesso', 'n'),
#   ('em', 'prp'),
#   ('a', 'art'),
#   ('chicane', 'n'),
#   (';', ';')],
#  [('«', '«'),
#   ('confesso', 'v-fin'),
#   ('que', 'conj-s'),
#   ('entrei', 'v-fin'),
#   ('depressa', 'adv'),
#   ('demais', 'adv'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('carro', 'n'),
#   ('atravessou-', 'v-fin'),
#   ('se', 'pron-pers'),
#   (',', ','),
#   ('primeiro', 'adv'),
#   ('para_a_direita', 'pp'),
#   ('e', 'conj-c'),
#   ('depois', 'adv'),
#   ('para', 'prp'),
#   ('a', 'art'),
#   ('esquerda', 'n'),
#   (',', ','),
#   ('o_que', 'pron-indp'),
#   ('me', 'pron-pers'),
#   ('levou', 'v-fin'),
#   ('a', 'prp'),
#   ('tirar', 'v-inf'),
#   ('o', 'art'),
#   ('pé', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('acelerador', 'n'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('resto', 'n'),
#   ('correu', 'v-fin'),
#   ('bem', 'adv'),
#   (',', ','),
#   ('mas', 'conj-c'),
#   ('a', 'art'),
#   ('volta', 'n'),
#   ('já', 'adv'),
#   ('estava', 'v-fin'),
#   ('comprometida', 'v-pcp'),
#   ('.', '.'),
#   ('»', '»')],
#  [('quanto_a', 'prp'),
#   ('pedro_matos_chaves', 'prop'),
#   (',', ','),
#   ('o', 'art'),
#   ('piloto', 'n'),
#   ('português', 'adj'),
#   ('esteve', 'v-fin'),
#   ('uns', 'pron-det'),
#   ('furos', 'n'),
#   ('abaixo_de', 'prp'),
#   ('o', 'art'),
#   ('habitual', 'adj'),
#   (',', ','),
#   ('não', 'adv'),
#   ('conseguindo', 'v-ger'),
#   ('com', 'prp'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('bmw', 'prop'),
#   ('série', 'n'),
#   ('3', 'num'),
#   ('melhor', 'adj'),
#   ('que', 'conj-s'),
#   ('o', 'art'),
#   ('oitavo', 'adj'),
#   ('tempo', 'n'),
#   (',', ','),
#   ('com', 'prp'),
#   ('1m14,667s', 'n'),
#   (',', ','),
#   ('o_que', 'pron-indp'),
#   ('o', 'pron-pers'),
#   ('deixou', 'v-fin'),
#   ('fora_de', 'prp'),
#   ('a', 'art'),
#   ('«', '«'),
#   ('super_pole', 'n'),
#   ('»', '»'),
#   ('.', '.')],
#  [('o', 'art'),
#   ('carro', 'n'),
#   ('alemão', 'adj'),
#   ('teimou', 'v-fin'),
#   ('em', 'prp'),
#   ('não', 'adv'),
#   ('se', 'pron-pers'),
#   ('adaptar', 'v-inf'),
#   ('a', 'prp'),
#   ('o', 'art'),
#   ('traçado', 'n'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('circuito', 'n'),
#   (',', ','),
#   ('o_que', 'pron-indp'),
#   ('deixou', 'v-fin'),
#   ('chaves', 'prop'),
#   ('algo', 'adv'),
#   ('desalentado', 'v-pcp'),
#   (',', ','),
#   ('até', 'adv'),
#   ('porque', 'conj-s'),
#   ('experimentava', 'v-fin'),
#   ('em', 'prp'),
#   ('barcelona', 'prop'),
#   ('algumas', 'pron-det'),
#   ('novidades', 'n'),
#   ('aerodinâmicas', 'adj'),
#   ('que', 'pron-indp'),
#   ('deveriam', 'v-fin'),
#   ('melhorar', 'v-inf'),
#   ('as', 'art'),
#   ('«', '«'),
#   ('performances', 'n'),
#   ('»', '»'),
#   ('de', 'prp'),
#   ('o', 'art'),
#   ('seu', 'pron-det'),
#   ('carro', 'n'),
#   ('.', '.')],
#  ...]

# %% [markdown]
# Now we can split our data into a train and a test set. Let's keep 100 sentences in the test set.

# %%
train = tsents[100:]
test = tsents[:100]

# %% [markdown]
# Let's see how we do with an unigram tagger, which simply assigns the most likely tag for any given token.

# %%
tagger1 = nltk.UnigramTagger(train)

# %% [markdown]
# We can check how the tagger performs on the test set by using the *evaluate* method, which gives us the model's accuracy.

# %%
tagger1.evaluate(test)
# Out:
# 0.8511016346837242

# %% [markdown]
# Try tagging a user-generated sentence. Don't forget to tokenize it and lower-case the obtained tokens, following what we have done with the corpus above. To tag a list of tokens, you can invoke the *tag* method on the tagger.

# %%
# your code here
import os

text = input("Enter review: ")
tagger1.tag(word_tokenize(text))
# Out:
# [('o', 'art'),
#  ('meu', 'pron-det'),
#  ('nome', 'n'),
#  ('é', 'v-fin'),
#  ('ines', None)]

# %% [markdown]
# We can now try out a bigram model for POS tagging, which will take into account the tag assigned to the previous word. If that previous word hasn't been seen in the training set, however, the model will fail to tag the target word, even if it did appear in the training set. For that reason, it is convenient to backoff to the previous unigram tagger -- if we know nothing about the tag of the previous word, we can still use the most likely tag for the target word.

# %%
tagger2 = nltk.BigramTagger(train, backoff=tagger1, verbose=True)
# Out:
# [Trained Unigram tagger: size=2003, backoff=73.09%, pruning=95.91%]

# %% [markdown]
# The *verbose* flag outputs some information, namely the amount of backoff used.
#
# Check the performance of this tagger, and compare it with the performance of a bigram tagger with no backoff strategy.

# %%
# your code here
tagger2.evaluate(test)
# Out:
# 0.8731343283582089

# %% [markdown]
# Build a trigram tagger with backoff to the bigram tagger and check its performance.

# %%
# your code here
tagger3 = nltk.TrigramTagger(train, backoff=tagger2, verbose=True)
tagger3.evaluate(test)
# Out:
# [Trained Unigram tagger: size=1638, backoff=80.09%, pruning=97.80%]
# 0.8749111584932481

# %% [markdown]
# ### Named Entity Recognition
#
# NER consists of detecting named entities in the text, which can correspond to several different categories, such as person names, organizations, dates, and so on.

# %% [markdown]
# #### Chunking
#
# Our first attempt to detect names in English may consist of chunking certain parts of the text that correspond to a pattern of POS tags. For that, we define a pattern consisting of (i) an optional *determinant*, optionally followed by (ii) *adjectives*, followed by (iii) a *noun*.
#
# We can use NLTK's *RegexpParser* and supply it with an appropriate regular expression.

# %%
# creating a chunk parser
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)

# %% [markdown]
# With our chunk parser, we can parse our sentence's POS-tagged list of tokens.

# %%
from nltk import word_tokenize
from nltk import pos_tag

text = """European authorities fined Google a record $5.1 billion on Wednesday 
for abusing its power in the mobile phone market and 
ordered the company to alter its practices."""
pos_tokens = pos_tag(word_tokenize(text))

# generating a parse tree
cs = cp.parse(pos_tokens)
print(cs)
# Out:
# (S
#   European/JJ
#   authorities/NNS
#   fined/VBD
#   Google/NNP
#   (NP a/DT record/NN)
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   (NP power/NN)
#   in/IN
#   (NP the/DT mobile/JJ phone/NN)
#   (NP market/NN)
#   and/CC
#   ordered/VBD
#   (NP the/DT company/NN)
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS
#   ./.)

# %% [markdown]
# A more appealing way of visualizing the result is to simply show the obtained parse tree, with *S* (for sentence) at the first level:

# %%
cs
# Out:
# The Ghostscript executable isn't found.
# See http://web.mit.edu/ghostscript/www/Install.htm
# If you're using a Mac, you can try installing
# https://docs.brew.sh/Installation then `brew install ghostscript`
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     813                     [
# --> 814                         find_binary(
#     815                             "gs",
#
# ~\anaconda3\lib\site-packages\nltk\internals.py in find_binary(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     686 ):
# --> 687     return next(
#     688         find_binary_iter(
#
# ~\anaconda3\lib\site-packages\nltk\internals.py in find_binary_iter(name, path_to_bin, env_vars, searchpath, binary_names, url, verbose)
#     672     """
# --> 673     yield from find_file_iter(
#     674         path_to_bin or name, env_vars, searchpath, binary_names, url, verbose
#
# ~\anaconda3\lib\site-packages\nltk\internals.py in find_file_iter(filename, env_vars, searchpath, file_names, url, verbose, finding_dir)
#     631         div = "=" * 75
# --> 632         raise LookupError(f"\n\n{div}\n{msg}\n{div}")
#     633
#
# LookupError:
#
# ===========================================================================
# NLTK was unable to find the gs file!
# Use software specific configuration parameters or set the PATH environment variable.
# ===========================================================================
#
# The above exception was the direct cause of the following exception:
#
# LookupError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\anaconda3\lib\site-packages\nltk\tree.py in _repr_png_(self)
#     831                 )
#     832                 print(pre_error_message, file=sys.stderr)
# --> 833                 raise LookupError from e
#     834
#     835             with open(out_path, "rb") as sr:
#
# LookupError:
# Tree('S', [('European', 'JJ'), ('authorities', 'NNS'), ('fined', 'VBD'), ('Google', 'NNP'), Tree('NP', [('a', 'DT'), ('record', 'NN')]), ('$', '$'), ('5.1', 'CD'), ('billion', 'CD'), ('on', 'IN'), ('Wednesday', 'NNP'), ('for', 'IN'), ('abusing', 'VBG'), ('its', 'PRP$'), Tree('NP', [('power', 'NN')]), ('in', 'IN'), Tree('NP', [('the', 'DT'), ('mobile', 'JJ'), ('phone', 'NN')]), Tree('NP', [('market', 'NN')]), ('and', 'CC'), ('ordered', 'VBD'), Tree('NP', [('the', 'DT'), ('company', 'NN')]), ('to', 'TO'), ('alter', 'VB'), ('its', 'PRP$'), ('practices', 'NNS'), ('.', '.')])

# %% [markdown]
# Based on the obtained chunks, we can generate IOB tags for each of the elements in the sentence. For each chunk, we will get a **B**egin tag for its first token, optionally followed by **I**nside tags for subsequent tokens in the chunk.

# %%
# generating IOB tags for the tree: one token per line, each with its POS tag and its named entity tag
from nltk.chunk import conlltags2tree, tree2conlltags
from pprint import pprint

iob_tagged = tree2conlltags(cs)
pprint(iob_tagged)
# Out:
# [('European', 'JJ', 'O'),
#  ('authorities', 'NNS', 'O'),
#  ('fined', 'VBD', 'O'),
#  ('Google', 'NNP', 'O'),
#  ('a', 'DT', 'B-NP'),
#  ('record', 'NN', 'I-NP'),
#  ('$', '$', 'O'),
#  ('5.1', 'CD', 'O'),
#  ('billion', 'CD', 'O'),
#  ('on', 'IN', 'O'),
#  ('Wednesday', 'NNP', 'O'),
#  ('for', 'IN', 'O'),
#  ('abusing', 'VBG', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('power', 'NN', 'B-NP'),
#  ('in', 'IN', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('mobile', 'JJ', 'I-NP'),
#  ('phone', 'NN', 'I-NP'),
#  ('market', 'NN', 'B-NP'),
#  ('and', 'CC', 'O'),
#  ('ordered', 'VBD', 'O'),
#  ('the', 'DT', 'B-NP'),
#  ('company', 'NN', 'I-NP'),
#  ('to', 'TO', 'O'),
#  ('alter', 'VB', 'O'),
#  ('its', 'PRP$', 'O'),
#  ('practices', 'NNS', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# NLTK provides a classifier that has already been trained to recognize named entities: [*ne_chunk*](https://www.nltk.org/book/ch07.html#duck_typing_index_term).

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\ineso\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# True

# %%
from nltk.chunk import ne_chunk

ne_tree = ne_chunk(pos_tokens)
print(ne_tree)
#ne_tree
# Out:
# (S
#   (GPE European/JJ)
#   authorities/NNS
#   fined/VBD
#   (PERSON Google/NNP)
#   a/DT
#   record/NN
#   $/$
#   5.1/CD
#   billion/CD
#   on/IN
#   Wednesday/NNP
#   for/IN
#   abusing/VBG
#   its/PRP$
#   power/NN
#   in/IN
#   the/DT
#   mobile/JJ
#   phone/NN
#   market/NN
#   and/CC
#   ordered/VBD
#   the/DT
#   company/NN
#   to/TO
#   alter/VB
#   its/PRP$
#   practices/NNS
#   ./.)

# %% [markdown]
# It's not the most perfect thing, is it?

# %% [markdown]
# ### spaCy
#
# SpaCy includes several [language processing pipelines](https://spacy.io/usage/processing-pipelines) that streamline several NLP tasks at once. We can use one of the available [trained pipelines](https://spacy.io/models).

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

# %% [markdown]
# #### Entity level
#
# SpaCy’s named entity recognition has been trained on the [OntoNotes 5](https://catalog.ldc.upenn.edu/LDC2013T19) corpus.
# We can directly obtain the entities identified by spaCy:

# %%
from pprint import pprint

doc = nlp("""European authorities fined Google a record $5.1 billion on Wednesday 
for abusing its power in the mobile phone market and 
ordered the company to alter its practices.""")

pprint([(X.text, X.label_) for X in doc.ents])
# Out:
# [('European', 'NORP'),
#  ('Google', 'ORG'),
#  ('$5.1 billion', 'MONEY'),
#  ('Wednesday', 'DATE')]

# %% [markdown]
# #### Token level
# We can also get the BIO encoding for the identified entities:

# %%
pprint([(X, X.ent_iob_, X.ent_type_) for X in doc])
# Out:
# [(European, 'B', 'NORP'),
#  (authorities, 'O', ''),
#  (fined, 'O', ''),
#  (Google, 'B', 'ORG'),
#  (a, 'O', ''),
#  (record, 'O', ''),
#  ($, 'B', 'MONEY'),
#  (5.1, 'I', 'MONEY'),
#  (billion, 'I', 'MONEY'),
#  (on, 'O', ''),
#  (Wednesday, 'B', 'DATE'),
#  (
# , 'O', ''),
#  (for, 'O', ''),
#  (abusing, 'O', ''),
#  (its, 'O', ''),
#  (power, 'O', ''),
#  (in, 'O', ''),
#  (the, 'O', ''),
#  (mobile, 'O', ''),
#  (phone, 'O', ''),
#  (market, 'O', ''),
#  (and, 'O', ''),
#  (
# , 'O', ''),
#  (ordered, 'O', ''),
#  (the, 'O', ''),
#  (company, 'O', ''),
#  (to, 'O', ''),
#  (alter, 'O', ''),
#  (its, 'O', ''),
#  (practices, 'O', ''),
#  (., 'O', '')]

# %% [markdown]
# #### NER from a document
# Let's use spaCy to do NER on an actual web document:

# %%
from bs4 import BeautifulSoup
import requests
import re

def url_to_string(url):
    res = requests.get(url)
    html = res.text
    soup = BeautifulSoup(html, 'html5lib')
    for script in soup(["script", "style", 'aside']):
        script.extract()
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

url = 'https://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.html?hp&action=click&pgtype=Homepage&clickSource=story-heading&module=first-column-region&region=top-news&WT.nav=top-news'
clean_text = url_to_string(url)
article = nlp(clean_text)

# %% [markdown]
# How many entities were extracted from the document?

# %%
# your code here
len(article.ents)
# Out:
# 164

# %% [markdown]
# How many instances are there for each entity type?

# %%
# your code here
instances = {}
for ent in article.ents:
    if ent.text not in instances:
        instances[ent.text] = 0
    instances[ent.text] += 1
instances
# Out:
# {'F.B.I.': 19,
#  'Peter Strzok': 4,
#  'Texts': 3,
#  'SectionsSEARCHSkip': 1,
#  'inToday': 1,
#  'PaperPolitics|F.B.I.': 1,
#  'byContinue': 1,
#  'storyF.B.I.': 1,
#  'storyAs': 1,
#  '10': 1,
#  'each month': 1,
#  'appPeter Strzok': 1,
#  'Trump': 11,
#  'T.J. Kirkpatrick': 1,
#  'The New York': 1,
#  'Adam Goldman': 1,
#  'Michael S. SchmidtAug': 1,
#  '13': 1,
#  '2018WASHINGTON': 1,
#  'Hillary Clinton': 2,
#  'Russia': 6,
#  'Strzok': 28,
#  'Monday': 2,
#  '2016': 3,
#  'Lisa Page': 1,
#  '20 years': 1,
#  'the early months': 1,
#  'last summer': 1,
#  'Robert S. Mueller III': 1,
#  'Twitter': 2,
#  'June': 1,
#  'the bureau’s Office of Professional Responsibility': 1,
#  '60 days': 1,
#  'House': 1,
#  'July': 1,
#  'David Bowdich': 1,
#  'the Office of Professional Responsibility': 1,
#  'Bowdich': 1,
#  'Christopher A. Wray': 1,
#  'Aitan Goelman': 1,
#  'Special Agent Strzok': 1,
#  'Wray': 1,
#  'Congress': 2,
#  'Goelman': 2,
#  'Americans': 1,
#  'Page': 3,
#  'one': 2,
#  'Michael E. Horowitz': 1,
#  'Clinton': 5,
#  'just weeks': 1,
#  'Horowitz': 3,
#  'Hundreds': 1,
#  'months': 1,
#  'Mueller': 2,
#  'May': 1,
#  'Midyear Exam': 1,
#  'late September 2016': 1,
#  'Anthony D. Weiner': 1,
#  'nearly a month': 1,
#  'Weiner': 2,
#  'Midyear': 1,
#  'last month': 2,
#  'USA': 1,
#  'Today': 1,
#  'James B. Comey': 1,
#  'their existence days': 1,
#  'second': 1,
#  'March': 1,
#  'Andrew G. McCabe': 1,
#  'McCabe': 1,
#  '48': 1,
#  'Georgetown University': 1,
#  'Army': 1,
#  'C.I.A.': 1,
#  'China': 1,
#  'Russian': 1,
#  'the United States': 1,
#  'Information Navigation©\xa02022': 1,
#  'The New York Times CompanyNYTCoContact UsAccessibilityWork': 1,
#  'ServiceTerms': 1}

# %% [markdown]
# Which are the most mentioned entities?

# %%
# your code here
entity = max(instances, key=instances.get)
print(entity, instances[entity])
# Out:
# Strzok 28

# %% [markdown]
# Checking out a specific sentence:

# %%
sentences = [x for x in article.sents]
a_sentence = sentences[20]
a_sentence
# Out:
# victory traces back to June, when Mr. Strzok’s conduct was laid out in a wide-ranging inspector general

# %% [markdown]
# Getting the BIO encoding for the sentence:

# %%
[(x, x.pos_, x.ent_iob_, x.ent_type_) for x in a_sentence]
# Out:
# [(victory, 'NOUN', 'O', ''),
#  (traces, 'VERB', 'O', ''),
#  (back, 'ADV', 'O', ''),
#  (to, 'ADP', 'O', ''),
#  (June, 'PROPN', 'B', 'DATE'),
#  (,, 'PUNCT', 'O', ''),
#  (when, 'ADV', 'O', ''),
#  (Mr., 'PROPN', 'O', ''),
#  (Strzok, 'PROPN', 'B', 'PERSON'),
#  (’s, 'PART', 'O', ''),
#  (conduct, 'NOUN', 'O', ''),
#  (was, 'AUX', 'O', ''),
#  (laid, 'VERB', 'O', ''),
#  (out, 'ADP', 'O', ''),
#  (in, 'ADP', 'O', ''),
#  (a, 'DET', 'O', ''),
#  (wide, 'ADV', 'O', ''),
#  (-, 'PUNCT', 'O', ''),
#  (ranging, 'VERB', 'O', ''),
#  (inspector, 'NOUN', 'O', ''),
#  (general, 'NOUN', 'O', '')]

# %% [markdown]
# We can simply output the mentioned entities and their categories:

# %%
dict([(str(x), x.label_) for x in a_sentence.ents])
# Out:
# {'June': 'DATE', 'Strzok': 'PERSON'}

# %% [markdown]
# We can also use spaCy's [visualizers](https://spacy.io/usage/visualizers) to better show the output of the NER model:

# %%
from spacy import displacy

displacy.render(a_sentence, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">victory traces back to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s conduct was laid out in a wide-ranging inspector general</div></span>

# %% [markdown]
#  The displaCy visualizer also gets us POS information and dependency parsing:

# %%
displacy.render(a_sentence, style='dep', jupyter = True, options = {'distance': 120})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="4e4cd55bd177469bbc3dc0f479240961-0" class="displacy" width="2330" height="557.0" direction="ltr" style="max-width: none; height: 557.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">victory</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="170">traces</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="170">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="290">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="290">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="530">June,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="530">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">when</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">Mr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="890">Strzok</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="890">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1010">’s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1010">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">conduct</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">laid</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">out</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1610">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1610">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1730">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1730">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">wide-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="1970">ranging</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1970">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2090">inspector</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2090">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="467.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">general</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e4cd55bd177469bbc3dc0f479240961-0-0" stroke-width="2px" d="M70,422.0 C70,362.0 140.0,362.0 140.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e4cd55bd177469bbc3dc0f479240961-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,424.0 L62,412.0 78,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e4cd55bd177469bbc3dc0f479240961-0-1" stroke-width="2px" d="M190,422.0 C190,362.0 260.0,362.0 260.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e4cd55bd177469bbc3dc0f479240961-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260.0,424.0 L268.0,412.0 252.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e4cd55bd177469bbc3dc0f479240961-0-2" stroke-width="2px" d="M310,422.0 C310,362.0 380.0,362.0 380.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e4cd55bd177469bbc3dc0f479240961-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,424.0 L388.0,412.0 372.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e4cd55bd177469bbc3dc0f479240961-0-3" stroke-width="2px" d="M430,422.0 C430,362.0 500.0,362.0 500.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e4cd55bd177469bbc3dc0f479240961-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M500.0,424.0 L508.0,412.0 492.0,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-4e4cd55bd177469bbc3dc0f479240961-0-4" stroke-width="2px" d="M670,422.0 C670,62.0 1365.0,62.0 1365.0,422.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-4e4cd55bd177469bbc3dc0f479240961-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,424.0 L662,412.0 678,412.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="dis

# %% [markdown]
# Extracting entities for the full document:

# %%
for sent in sentences:
    displacy.render(sent, jupyter=True, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is Fired - The New York Times                                                                                                                         </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SectionsSEARCHSkip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div></span>
# C:\Users\ineso\anaconda3\lib\site-packages\spacy\displacy\__init__.py:189: UserWarning: [W006] No entities to visualize found in Doc object. If this is surprising to you, make sure the Doc was processed using a model that supports named entity recognition, and check the `doc.ents` property manually if necessary.
#   warnings.warn(Warnings.W006)
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">to contentSkip to site indexPoliticsLog </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     inToday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PaperPolitics|F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Is Firedhttps://www.nytimes.com/2018/08/13/us/politics/peter-strzok-fired-fbi.htmlGive </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">this article1626AdvertisementContinue reading the main storySupported
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  reading the main
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     storyF.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Agent
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Who Criticized Trump in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Texts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">, Is FiredSend any friend a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     storyAs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  a subscriber, you have
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  gift articles to give
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     each month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Anyone can read what you share.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Give this article1626Read in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     appPeter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , a top
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  counterintelligence agent who was taken off the special counsel investigation after his disparaging texts about President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  were uncovered, was fired.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Credit...</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     T.J. Kirkpatrick
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  for
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  TimesBy
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Adam Goldman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael S. SchmidtAug
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ,
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2018WASHINGTON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  —
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Peter Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  senior counterintelligence agent who disparaged President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in inflammatory text messages and helped oversee the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  email and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  investigations, has been fired for violating bureau policies, Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s lawyer said
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Trump and his allies seized on the texts — exchanged during the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  campaign with a former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  lawyer,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Lisa Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  — in assailing the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  investigation as an illegitimate “witch hunt.” </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who rose over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     20 years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  at the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to become one of its most experienced counterintelligence agents, was a key figure in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the early months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  of the inquiry.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Along with writing the texts, Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was accused of sending a highly sensitive search warrant to his personal email account.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  had been under immense political pressure by Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  to dismiss Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who was removed
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last summer
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  from the staff of the special counsel,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Robert S. Mueller III
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The president has repeatedly denounced Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  in posts on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  expressed satisfaction that he had been sacked.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">victory traces back to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , when Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s conduct was laid out in a wide-ranging inspector general</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">’s report on how the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  handled the investigation of
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hillary Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s emails in the run-up to the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  election. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The report was critical of Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s conduct in sending the texts, and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the bureau’s Office of Professional Responsibility
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  said that Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  should be suspended for
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     60 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and demoted. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had testified before the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  about how he had not allowed his political views to interfere with the investigations he was overseeing.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">But Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s lawyer said the deputy director of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     David Bowdich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , had overruled
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Office of Professional Responsibility
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and fired Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">A spokeswoman for the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  did not respond to a message seeking comment about why Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  was dismissed rather than demoted. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Firing Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , however, removes a favorite target of Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from the ranks of the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and gives Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bowdich
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Christopher A. Wray
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , a chance to move beyond the president’s ire.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Aitan Goelman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s lawyer, denounced his client’s dismissal. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“The decision to fire
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Special Agent Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  is not only a departure from typical bureau practice, but also contradicts Director
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wray
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s testimony to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and his assurances that the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  intended to follow its regular process in this and all personnel matters,” Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goelman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“This decision should be deeply troubling to all
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ,” Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Goelman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  added. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“A lengthy investigation and multiple rounds of congressional testimony failed to produce a shred of evidence that Special Agent Strzok’s personal views ever affected his work.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">”Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Strzok’s text exchanges with Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  demonstrated animosity toward Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# , Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Page
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  asks: Trump is “not ever going to become president, right? </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Right?!” </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  responds: “No. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">No he won’t. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">We’ll stop it.” </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The inspector general, who uncovered the messages, found no evidence that the pair imposed their political views on their investigative decisions but cited that exchange as “not only indicative of a biased state of mind but, even more seriously, implies a willingness to take official action to impact the presidential candidate’s electoral prospects.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">”The report by the inspector general,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Michael E. Horowitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , that preceded Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s firing not only criticized his conduct in sending the texts but also his use of personal email accounts to handle sensitive information. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In addition, the inspector general criticized Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s decision not to move swiftly to examine new emails related to the
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  investigation
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  before the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2016
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  election.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Horowitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said in his report that he was “deeply troubled” by the text messages. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hundreds
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  exchanged over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     months
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  were found in which the pair disparaged Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  and, to a lesser extent, Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , exchanged work gossip and bantered.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">On
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  said he was “deeply saddened by this decision,” adding, “It has been an honor to serve my country and work with the fine men and women of the FBI.”Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Strzok became emblematic of Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s unfounded assertions that a so-called deep state of bureaucrats opposed to him was undermining his presidency. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  contended that Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  targeted the president and accused Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  of being “treasonous” and a “disgrace.” </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  told lawmakers that he never leaked information about the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inquiry, which could have upended the election and hurt Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s chances of becoming president.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">After Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Horowitz
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  uncovered the texts, Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Mueller
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who had by then taken over the investigation, removed Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  from his team. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He was reassigned to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ’s human resources division. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Ms.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Page
# ...
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had slow-walked the examination of the new emails to help Mrs.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clinton
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s presidential bid.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“Under these circumstances, we did not have confidence that Strzok’s decision to prioritize the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  investigation over following up on the
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Midyear
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# -related investigative lead discovered on the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Weiner
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  laptop was free from bias,” he wrote.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The delays were merely the “result of bureaucratic snafus,” Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s lawyer wrote
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     USA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Today
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">But the justifications for the delay were “unpersuasive” and had “far-reaching consequences,” the inspector general said. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     James B. Comey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the former
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  director, has told investigators that if he had known about the emails earlier, it might have influenced his decision to alert
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Congress
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  to
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     their existence days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  before the election.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In addition, the inspector general said that Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  had forwarded a proposed search warrant to his personal email account. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The inspector general said the email, which included a draft of the search warrant affidavit, contained information that appeared to be under seal.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In a heated congressional hearing
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     last month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Strzok
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  expressed “significant regret” for the texts and rebutted the president’s attacks on the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  inquiry. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">“This investigation is not politically motivated; it is not a witch hunt; it is not a hoax,” he said.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Strzok’s dismissal was not unexpected. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He is the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     second
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  senior
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  agent to be fired as a result of the inspector general’s investigation. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Andrew G. McCabe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the former deputy director, was fired after the inspector general repeatedly faulted him for misleading investigators.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The firing was politically motivated, Mr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     McCabe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has said, as an effort to discredit him as a witness in the special counsel investigation.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Both men were fired before they were eligible for their pension and health benefits.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Mr. </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Strzok,
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     48
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , a graduate of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Georgetown University
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , served as an officer in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Army
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  before he joined the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He held several key positions in the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     F.B.I.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , eventually becoming a top deputy in the counterintelligence division.</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">He handled many important espionage cases including
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  involving a former
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     C.I.A.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  officer suspected of working for
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     China
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and a group of
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  spies who had been working undercover in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# .</div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">AdvertisementContinue reading the main storySite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Information Navigation© 2022
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  </div></span>
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times CompanyNYTCoContact UsAccessibilityWork
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  with usAdvertiseT Brand StudioYour Ad ChoicesPrivacy PolicyTerms of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ServiceTerms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of SaleSite MapCanadaInternationalHelpSubscriptions                                                                                       </div></span>

# %% [markdown]
# #### NER for other languages
#
# Try out other spaCy [pipelines](https://spacy.io/models) for other languages!

# %%
# your code here
